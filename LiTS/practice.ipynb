# %%
import os, torch, random
import numpy as np

device = 'cuda' if torch.cuda.is_available() else 'cpu'

CFG = {"SEED": 42,
       "TEST_PORTION": 0.3,
       "EPOCHS": 30,
       "BATCH_SIZE": 16,
       "LR": 1e-4}

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED']=str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=True
    return

# %%
root = "D:/Datasets/Liver/"

def path_dict(root):
    total_dict = {}
    for ID in os.listdir(root):
        date_dict = {}
        for date in os.listdir(f"{root}{ID}/"):
            path_list = []
            for item in os.listdir(f"{root}{ID}/{date}/"):
                if item == "Seg":
                    path_list.append(f"{root}{ID}/{date}/{item}/liver.nii.gz")
                elif ".nii" in item:
                    path_list.append(f"{root}{ID}/{date}/{item}")
            date_dict[date] = path_list
        total_dict[ID] = date_dict
    return total_dict

# %%
path_dict(root)
# Out:
# {'1011830': {'20180723': ['D:/Datasets/Liver/1011830/20180723/A.nii.gz',
#    'D:/Datasets/Liver/1011830/20180723/D.nii.gz',
#    'D:/Datasets/Liver/1011830/20180723/label.nii.gz',
#    'D:/Datasets/Liver/1011830/20180723/P.nii.gz',
#    'D:/Datasets/Liver/1011830/20180723/Seg/liver.nii.gz'],
#   '20181128': ['D:/Datasets/Liver/1011830/20181128/A.nii.gz',
#    'D:/Datasets/Liver/1011830/20181128/D.nii.gz',
#    'D:/Datasets/Liver/1011830/20181128/label.nii.gz',
#    'D:/Datasets/Liver/1011830/20181128/P.nii.gz',
#    'D:/Datasets/Liver/1011830/20181128/Seg/liver.nii.gz']},
#  '1070799': {'20200513': ['D:/Datasets/Liver/1070799/20200513/A.nii.gz',
#    'D:/Datasets/Liver/1070799/20200513/D.nii.gz',
#    'D:/Datasets/Liver/1070799/20200513/label.nii.gz',
#    'D:/Datasets/Liver/1070799/20200513/P.nii.gz',
#    'D:/Datasets/Liver/1070799/20200513/Seg/liver.nii.gz'],
#   '20200812': ['D:/Datasets/Liver/1070799/20200812/A.nii.gz',
#    'D:/Datasets/Liver/1070799/20200812/D.nii.gz',
#    'D:/Datasets/Liver/1070799/20200812/label.nii.gz',
#    'D:/Datasets/Liver/1070799/20200812/P.nii.gz',
#    'D:/Datasets/Liver/1070799/20200812/Seg/liver.nii.gz']},
#  '1099917': {'20190418': ['D:/Datasets/Liver/1099917/20190418/A.nii.gz',
#    'D:/Datasets/Liver/1099917/20190418/D.nii.gz',
#    'D:/Datasets/Liver/1099917/20190418/label.nii.gz',
#    'D:/Datasets/Liver/1099917/20190418/P.nii.gz',
#    'D:/Datasets/Liver/1099917/20190418/Seg/liver.nii.gz'],
#   '20190911': ['D:/Datasets/Liver/1099917/20190911/A.nii.gz',
#    'D:/Datasets/Liver/1099917/20190911/D.nii.gz',
#    'D:/Datasets/Liver/1099917/20190911/label.nii.gz',
#    'D:/Datasets/Liver/1099917/20190911/P.nii.gz',
#    'D:/Datasets/Liver/1099917/20190911/Seg/liver.nii.gz']},
#  '1125503': {'20171207': ['D:/Datasets/Liver/1125503/20171207/A.nii.gz',
#    'D:/Datasets/Liver/1125503/20171207/D.nii.gz',
#    'D:/Datasets/Liver/1125503/20171207/label.nii.gz',
#    'D:/Datasets/Liver/1125503/20171207/P.nii.gz',
#    'D:/Datasets/Liver/1125503/20171207/Seg/liver.nii.gz'],
#   '20180308': ['D:/Datasets/Liver/1125503/20180308/A.nii.gz',
#    'D:/Datasets/Liver/1125503/20180308/D.nii.gz',
#    'D:/Datasets/Liver/1125503/20180308/label.nii.gz',
#    'D:/Datasets/Liver/1125503/20180308/P.nii.gz',
#    'D:/Datasets/Liver/1125503/20180308/Seg/liver.nii.gz']},
#  '1229736': {'20200615': ['D:/Datasets/Liver/1229736/20200615/A.nii.gz',
#    'D:/Datasets/Liver/1229736/20200615/D.nii.gz',
#    'D:/Datasets/Liver/1229736/20200615/label.nii.gz',
#    'D:/Datasets/Liver/1229736/20200615/P.nii.gz',
#    'D:/Datasets/Liver/1229736/20200615/Seg/liver.nii.gz'],
#   '20200909': ['D:/Datasets/Liver/1229736/20200909/A.nii.gz',
#    'D:/Datasets/Liver/1229736/20200909/D.nii.gz',
#    'D:/Datasets/Liver/1229736/20200909/label.nii.gz',
#    'D:/Datasets/Liver/1229736/20200909/P.nii.gz',
#    'D:/Datasets/Liver/1229736/20200909/Seg/liver.nii.gz']},
#  '1232268': {'20180710': ['D:/Datasets/Liver/1232268/20180710/A.nii.gz',
#    'D:/Datasets/Liver/1232268/20180710/D.nii.gz',
#    'D:/Datasets/Liver/1232268/20180710/label.nii.gz',
#    'D:/Datasets/Liver/1232268/20180710/P.nii.gz',
#    'D:/Datasets/Liver/1232268/20180710/Seg/liver.nii.gz']},
#  '1298212': {'20190605': ['D:/Datasets/Liver/1298212/20190605/A.nii.gz',
#    'D:/Datasets/Liver/1298212/20190605/D.nii.gz',
#    'D:/Datasets/Liver/1298212/20190605/label.nii.gz',
#    'D:/Datasets/Liver/1298212/20190605/P.nii.gz',
#    'D:/Datasets/Liver/1298212/20190605/Seg/liver.nii.gz'],
#   '20190904': ['D:/Datasets/Liver/1298212/20190904/A.nii.gz',
#    'D:/Datasets/Liver/1298212/20190904/D.nii.gz',
#    'D:/Datasets/Liver/1298212/20190904/label.nii.gz',
#    'D:/Datasets/Liver/1298212/20190904/P.nii.gz',
#    'D:/Datasets/Liver/1298212/20190904/Seg/liver.nii.gz']},
#  '1309662': {'20201007': ['D:/Datasets/Liver/1309662/20201007/A.nii.gz',
#    'D:/Datasets/Liver/1309662/20201007/D.nii.gz',
#    'D:/Datasets/Liver/1309662/20201007/label.nii.gz',
#    'D:/Datasets/Liver/1309662/20201007/P.nii.gz',
#    'D:/Datasets/Liver/1309662/20201007/Seg/liver.nii.gz'],
#   '20210112': ['D:/Datasets/Liver/1309662/20210112/A.nii.gz',
#    'D:/Datasets/Liver/1309662/20210112/D.nii.gz',
#    'D:/Datasets/Liver/1309662/20210112/label.nii.gz',
#    'D:/Datasets/Liver/1309662/20210112/P.nii.gz',
#    'D:/Datasets/Liver/1309662/20210112/Seg/liver.nii.gz']},
#  '13096621': {'20180621': ['D:/Datasets/Liver/13096621/20180621/A.nii.gz',
#    'D:/Datasets/Liver/13096621/20180621/D.nii.gz',
#    'D:/Datasets/Liver/13096621/20180621/label.nii.gz',
#    'D:/Datasets/Liver/13096621/20180621/P.nii.gz',
#    'D:/Datasets/Liver/13096621/20180621/Seg/liver.nii.gz'],
#   '20180920': ['D:/Datasets/Liver/13096621/20180920/A.nii.gz',
#    'D:/Datasets/Liver/13096621/20180920/D.nii.gz',
#    'D:/Datasets/Liver/13096621/20180920/label.nii.gz',
#    'D:/Datasets/Liver/13096621/20180920/P.nii.gz',
#    'D:/Datasets/Liver/13096621/20180920/Seg/liver.nii.gz'],
#   '20190321': ['D:/Datasets/Liver/13096621/20190321/A.nii.gz',
#    'D:/Datasets/Liver/13096621/20190321/D.nii.gz',
#    'D:/Datasets/Liver/13096621/20190321/label.nii.gz',
#    'D:/Datasets/Liver/13096621/20190321/P.nii.gz',
#    'D:/Datasets/Liver/13096621/20190321/Seg/liver.nii.gz']},
#  '1378496': {'20200727': ['D:/Datasets/Liver/1378496/20200727/A.nii.gz',
#    'D:/Datasets/Liver/1378496/20200727/D.nii.gz',
#    'D:/Datasets/Liver/1378496/20200727/label.nii.gz',
#    'D:/Datasets/Liver/1378496/20200727/P.nii.gz',
#    'D:/Datasets/Liver/1378496/20200727/Seg/liver.nii.gz'],
#   '20201103': ['D:/Datasets/Liver/1378496/20201103/A.nii.gz',
#    'D:/Datasets/Liver/1378496/20201103/D.nii.gz',
#    'D:/Datasets/Liver/1378496/20201103/label.nii.gz',
#    'D:/Datasets/Liver/1378496/20201103/P.nii.gz',
#    'D:/Datasets/Liver/1378496/20201103/Seg/liver.nii.gz'],
#   '20210202': ['D:/Datasets/Liver/1378496/20210202/A.nii.gz',
#    'D:/Datasets/Liver/1378496/20210202/D.nii.gz',
#    'D:/Datasets/Liver/1378496/20210202/label.nii.gz',
#    'D:/Datasets/Liver/1378496/20210202/P.nii.gz',
#    'D:/Datasets/Liver/1378496/20210202/Seg/liver.nii.gz']},
#  '13784961': {'20190722': ['D:/Datasets/Liver/13784961/20190722/A.nii.gz',
#    'D:/Datasets/Liver/13784961/20190722/D.nii.gz',
#    'D:/Datasets/Liver/13784961/20190722/label.nii.gz',
#    'D:/Datasets/Liver/13784961/20190722/P.nii.gz',
#    'D:/Datasets/Liver/13784961/20190722/Seg/liver.nii.gz'],
#   '20191022': ['D:/Datasets/Liver/13784961/20191022/A.nii.gz',
#    'D:/Datasets/Liver/13784961/20191022/D.nii.gz',
#    'D:/Datasets/Liver/13784961/20191022/label.nii.gz',
#    'D:/Datasets/Liver/13784961/20191022/P.nii.gz',
#    'D:/Datasets/Liver/13784961/20191022/Seg/liver.nii.gz'],
#   '20200129': ['D:/Datasets/Liver/13784961/20200129/A.nii.gz',
#    'D:/Datasets/Liver/13784961/20200129/D.nii.gz',
#    'D:/Datasets/Liver/13784961/20200129/label.nii.gz',
#    'D:/Datasets/Liver/13784961/20200129/P.nii.gz',
#    'D:/Datasets/Liver/13784961/20200129/Seg/liver.nii.gz']},
#  '1384942': {'20191007': ['D:/Datasets/Liver/1384942/20191007/A.nii.gz',
#    'D:/Datasets/Liver/1384942/20191007/D.nii.gz',
#    'D:/Datasets/Liver/1384942/20191007/label.nii.gz',
#    'D:/Datasets/Liver/1384942/20191007/P.nii.gz',
#    'D:/Datasets/Liver/1384942/20191007/Seg/liver.nii.gz'],
#   '20200414': ['D:/Datasets/Liver/1384942/20200414/A.nii.gz',
#    'D:/Datasets/Liver/1384942/20200414/D.nii.gz',
#    'D:/Datasets/Liver/1384942/20200414/label.nii.gz',
#    'D:/Datasets/Liver/1384942/20200414/P.nii.gz',
#    'D:/Datasets/Liver/1384942/20200414/Seg/liver.nii.gz']},
#  '1389347': {'20180830': ['D:/Datasets/Liver/1389347/20180830/A.nii.gz',
#    'D:/Datasets/Liver/1389347/20180830/D.nii.gz',
#    'D:/Datasets/Liver/1389347/20180830/label.nii.gz',
#    'D:/Datasets/Liver/1389347/20180830/P.nii.gz',
#    'D:/Datasets/Liver/1389347/20180830/Seg/liver.nii.gz'],
#   '20181122': ['D:/Datasets/Liver/1389347/20181122/A.nii.gz',
#    'D:/Datasets/Liver/1389347/20181122/D.nii.gz',
#    'D:/Datasets/Liver/1389347/20181122/label.nii.gz',
#    'D:/Datasets/Liver/1389347/20181122/P.nii.gz',
#    'D:/Datasets/Liver/1389347/20181122/Seg/liver.nii.gz']},
#  '1395582': {'20190618': ['D:/Datasets/Liver/1395582/20190618/A.nii.gz',
#    'D:/Datasets/Liver/1395582/20190618/D.nii.gz',
#    'D:/Datasets/Liver/1395582/20190618/label.nii.gz',
#    'D:/Datasets/Liver/1395582/20190618/P.nii.gz',
#    'D:/Datasets/Liver/1395582/20190618/Seg/liver.nii.gz'],
#   '20190916': ['D:/Datasets/Liver/1395582/20190916/A.nii.gz',
#    'D:/Datasets/Liver/1395582/20190916/D.nii.gz',
#    'D:/Datasets/Liver/1395582/20190916/label.nii.gz',
#    'D:/Datasets/Liver/1395582/20190916/P.nii.gz',
#    'D:/Datasets/Liver/1395582/20190916/Seg/liver.nii.gz']},
#  '1441663': {'20180220': ['D:/Datasets/Liver/1441663/20180220/A.nii.gz',
#    'D:/Datasets/Liver/1441663/20180220/D.nii.gz',
#    'D:/Datasets/Liver/1441663/20180220/label.nii.gz',
#    'D:/Datasets/Liver/1441663/20180220/P.nii.gz',
#    'D:/Datasets/Liver/1441663/20180220/Seg/liver.nii.gz'],
#   '20180724': ['D:/Datasets/Liver/1441663/20180724/A.nii.gz',
#    'D:/Datasets/Liver/1441663/20180724/D.nii.gz',
#    'D:/Datasets/Liver/1441663/20180724/label.nii.gz',
#    'D:/Datasets/Liver/1441663/20180724/P.nii.gz',
#    'D:/Datasets/Liver/1441663/20180724/Seg/liver.nii.gz']},
#  '1446704': {'20190826': ['D:/Datasets/Liver/1446704/20190826/A.nii.gz',
#    'D:/Datasets/Liver/1446704/20190826/D.nii.gz',
#    'D:/Datasets/Liver/1446704/20190826/label.nii.gz',
#    'D:/Datasets/Liver/1446704/20190826/P.nii.gz',
#    'D:/Datasets/Liver/1446704/20190826/Seg/liver.nii.gz'],
#   '20200309': ['D:/Datasets/Liver/1446704/20200309/A.nii.gz',
#    'D:/Datasets/Liver/1446704/20200309/D.nii.gz',
#    'D:/Datasets/Liver/1446704/20200309/label.nii.gz',
#    'D:/Datasets/Liver/1446704/20200309/P.nii.gz',
#    'D:/Datasets/Liver/1446704/20200309/Seg/liver.nii.gz']},
#  '1471406': {'20190827': ['D:/Datasets/Liver/1471406/20190827/A.nii.gz',
#    'D:/Datasets/Liver/1471406/20190827/D.nii.gz',
#    'D:/Datasets/Liver/1471406/20190827/label.nii.gz',
#    'D:/Datasets/Liver/1471406/20190827/P.nii.gz',
#    'D:/Datasets/Liver/1471406/20190827/Seg/liver.nii.gz'],
#   '20200403': ['D:/Datasets/Liver/1471406/20200403/A.nii.gz',
#    'D:/Datasets/Liver/1471406/20200403/D.nii.gz',
#    'D:/Datasets/Liver/1471406/20200403/label.nii.gz',
#    'D:/Datasets/Liver/1471406/20200403/P.nii.gz',
#    'D:/Datasets/Liver/1471406/20200403/Seg/liver.nii.gz']},
#  '1483320': {'20181012': ['D:/Datasets/Liver/1483320/20181012/A.nii.gz',
#    'D:/Datasets/Liver/1483320/20181012/D.nii.gz',
#    'D:/Datasets/Liver/1483320/20181012/label.nii.gz',
#    'D:/Datasets/Liver/1483320/20181012/P.nii.gz',
#    'D:/Datasets/Liver/1483320/20181012/Seg/liver.nii.gz']},
#  '1532293': {'20190509': ['D:/Datasets/Liver/1532293/20190509/A.nii.gz',
#    'D:/Datasets/Liver/1532293/20190509/D.nii.gz',
#    'D:/Datasets/Liver/1532293/20190509/label.nii.gz',
#    'D:/Datasets/Liver/1532293/20190509/P.nii.gz',
#    'D:/Datasets/Liver/1532293/20190509/Seg/liver.nii.gz'],
#   '20190814': ['D:/Datasets/Liver/1532293/20190814/A.nii.gz',
#    'D:/Datasets/Liver/1532293/20190814/D.nii.gz',
#    'D:/Datasets/Liver/1532293/20190814/label.nii.gz',
#    'D:/Datasets/Liver/1532293/20190814/P.nii.gz',
#    'D:/Datasets/Liver/1532293/20190814/Seg/liver.nii.gz']},
#  '1532645': {'20180117': ['D:/Datasets/Liver/1532645/20180117/A.nii.gz',
#    'D:/Datasets/Liver/1532645/20180117/D.nii.gz',
#    'D:/Datasets/Liver/1532645/20180117/label.nii.gz',
#    'D:/Datasets/Liver/1532645/20180117/P.nii.gz',
#    'D:/Datasets/Liver/1532645/20180117/Seg/liver.nii.gz'],
#   '20180509': ['D:/Datasets/Liver/1532645/20180509/A.nii.gz',
#    'D:/Datasets/Liver/1532645/20180509/D.nii.gz',
#    'D:/Datasets/Liver/1532645/20180509/label.nii.gz',
#    'D:/Datasets/Liver/1532645/20180509/P.nii.gz',
#    'D:/Datasets/Liver/1532645/20180509/Seg/liver.nii.gz']},
#  '1533654': {'20180222': ['D:/Datasets/Liver/1533654/20180222/A.nii.gz',
#    'D:/Datasets/Liver/1533654/20180222/D.nii.gz',
#    'D:/Datasets/Liver/1533654/20180222/label.nii.gz',
#    'D:/Datasets/Liver/1533654/20180222/P.nii.gz',
#    'D:/Datasets/Liver/1533654/20180222/Seg/liver.nii.gz'],
#   '20180911': ['D:/Datasets/Liver/1533654/20180911/A.nii.gz',
#    'D:/Datasets/Liver/1533654/20180911/D.nii.gz',
#    'D:/Datasets/Liver/1533654/20180911/label.nii.gz',
#    'D:/Datasets/Liver/1533654/20180911/P.nii.gz',
#    'D:/Datasets/Liver/1533654/20180911/Seg/liver.nii.gz']},
#  '1536028': {'20190326': ['D:/Datasets/Liver/1536028/20190326/A.nii.gz',
#    'D:/Datasets/Liver/1536028/20190326/D.nii.gz',
#    'D:/Datasets/Liver/1536028/20190326/label.nii.gz',
#    'D:/Datasets/Liver/1536028/20190326/P.nii.gz',
#    'D:/Datasets/Liver/1536028/20190326/Seg/liver.nii.gz'],
#   '20190902': ['D:/Datasets/Liver/1536028/20190902/A.nii.gz',
#    'D:/Datasets/Liver/1536028/20190902/D.nii.gz',
#    'D:/Datasets/Liver/1536028/20190902/label.nii.gz',
#    'D:/Datasets/Liver/1536028/20190902/P.nii.gz',
#    'D:/Datasets/Liver/1536028/20190902/Seg/liver.nii.gz']},
#  '1541326': {'20210202': ['D:/Datasets/Liver/1541326/20210202/A.nii.gz',
#    'D:/Datasets/Liver/1541326/20210202/D.nii.gz',
#    'D:/Datasets/Liver/1541326/20210202/label.nii.gz',
#    'D:/Datasets/Liver/1541326/20210202/P.nii.gz',
#    'D:/Datasets/Liver/1541326/20210202/Seg/liver.nii.gz']},
#  '1556475': {'20170201': ['D:/Datasets/Liver/1556475/20170201/A.nii.gz',
#    'D:/Datasets/Liver/1556475/20170201/D.nii.gz',
#    'D:/Datasets/Liver/1556475/20170201/label.nii.gz',
#    'D:/Datasets/Liver/1556475/20170201/P.nii.gz',
#    'D:/Datasets/Liver/1556475/20170201/Seg/liver.nii.gz'],
#   '20170510': ['D:/Datasets/Liver/1556475/20170510/A.nii.gz',
#    'D:/Datasets/Liver/1556475/20170510/D.nii.gz',
#    'D:/Datasets/Liver/1556475/20170510/label.nii.gz',
#    'D:/Datasets/Liver/1556475/20170510/P.nii.gz',
#    'D:/Datasets/Liver/1556475/20170510/Seg/liver.nii.gz'],
#   '20170913': ['D:/Datasets/Liver/1556475/20170913/A.nii.gz',
#    'D:/Datasets/Liver/1556475/20170913/D.nii.gz',
#    'D:/Datasets/Liver/1556475/20170913/label.nii.gz',
#    'D:/Datasets/Liver/1556475/20170913/P.nii.gz',
#    'D:/Datasets/Liver/1556475/20170913/Seg/liver.nii.gz']},
#  '1570921': {'20180619': ['D:/Datasets/Liver/1570921/20180619/A.nii.gz',
#    'D:/Datasets/Liver/1570921/20180619/D.nii.gz',
#    'D:/Datasets/Liver/1570921/20180619/label.nii.gz',
#    'D:/Datasets/Liver/1570921/20180619/P.nii.gz',
#    'D:/Datasets/Liver/1570921/20180619/Seg/liver.nii.gz'],
#   '20180918': ['D:/Datasets/Liver/1570921/20180918/A.nii.gz',
#    'D:/Datasets/Liver/1570921/20180918/D.nii.gz',
#    'D:/Datasets/Liver/1570921/20180918/label.nii.gz',
#    'D:/Datasets/Liver/1570921/20180918/P.nii.gz',
#    'D:/Datasets/Liver/1570921/20180918/Seg/liver.nii.gz']},
#  '1619006': {'20170508': ['D:/Datasets/Liver/1619006/20170508/A.nii.gz',
#    'D:/Datasets/Liver/1619006/20170508/D.nii.gz',
#    'D:/Datasets/Liver/1619006/20170508/label.nii.gz',
#    'D:/Datasets/Liver/1619006/20170508/P.nii.gz',
#    'D:/Datasets/Liver/1619006/20170508/Seg/liver.nii.gz'],
#   '20171218': ['D:/Datasets/Liver/1619006/20171218/A.nii.gz',
#    'D:/Datasets/Liver/1619006/20171218/D.nii.gz',
#    'D:/Datasets/Liver/1619006/20171218/label.nii.gz',
#    'D:/Datasets/Liver/1619006/20171218/P.nii.gz',
#    'D:/Datasets/Liver/1619006/20171218/Seg/liver.nii.gz']},
#  '1622877': {'20200219': ['D:/Datasets/Liver/1622877/20200219/A.nii.gz',
#    'D:/Datasets/Liver/1622877/20200219/D.nii.gz',
#    'D:/Datasets/Liver/1622877/20200219/label.nii.gz',
#    'D:/Datasets/Liver/1622877/20200219/P.nii.gz',
#    'D:/Datasets/Liver/1622877/20200219/Seg/liver.nii.gz'],
#   '20200616': ['D:/Datasets/Liver/1622877/20200616/A.nii.gz',
#    'D:/Datasets/Liver/1622877/20200616/D.nii.gz',
#    'D:/Datasets/Liver/1622877/20200616/label.nii.gz',
#    'D:/Datasets/Liver/1622877/20200616/P.nii.gz',
#    'D:/Datasets/Liver/1622877/20200616/Seg/liver.nii.gz']},
#  '1631616': {'20180418': ['D:/Datasets/Liver/1631616/20180418/A.nii.gz',
#    'D:/Datasets/Liver/1631616/20180418/D.nii.gz',
#    'D:/Datasets/Liver/1631616/20180418/label.nii.gz',
#    'D:/Datasets/Liver/1631616/20180418/P.nii.gz',
#    'D:/Datasets/Liver/1631616/20180418/Seg/liver.nii.gz'],
#   '20181008': ['D:/Datasets/Liver/1631616/20181008/A.nii.gz',
#    'D:/Datasets/Liver/1631616/20181008/D.nii.gz',
#    'D:/Datasets/Liver/1631616/20181008/label.nii.gz',
#    'D:/Datasets/Liver/1631616/20181008/P.nii.gz',
#    'D:/Datasets/Liver/1631616/20181008/Seg/liver.nii.gz']},
#  '1665416': {'20180625': ['D:/Datasets/Liver/1665416/20180625/A.nii.gz',
#    'D:/Datasets/Liver/1665416/20180625/D.nii.gz',
#    'D:/Datasets/Liver/1665416/20180625/label.nii.gz',
#    'D:/Datasets/Liver/1665416/20180625/P.nii.gz',
#    'D:/Datasets/Liver/1665416/20180625/Seg/liver.nii.gz'],
#   '20190109': ['D:/Datasets/Liver/1665416/20190109/A.nii.gz',
#    'D:/Datasets/Liver/1665416/20190109/D.nii.gz',
#    'D:/Datasets/Liver/1665416/20190109/label.nii.gz',
#    'D:/Datasets/Liver/1665416/20190109/P.nii.gz',
#    'D:/Datasets/Liver/1665416/20190109/Seg/liver.nii.gz']},
#  '1678064': {'20171011': ['D:/Datasets/Liver/1678064/20171011/A.nii.gz',
#    'D:/Datasets/Liver/1678064/20171011/D.nii.gz',
#    'D:/Datasets/Liver/1678064/20171011/label.nii.gz',
#    'D:/Datasets/Liver/1678064/20171011/P.nii.gz',
#    'D:/Datasets/Liver/1678064/20171011/Seg/liver.nii.gz'],
#   '20180227': ['D:/Datasets/Liver/1678064/20180227/A.nii.gz',
#    'D:/Datasets/Liver/1678064/20180227/D.nii.gz',
#    'D:/Datasets/Liver/1678064/20180227/label.nii.gz',
#    'D:/Datasets/Liver/1678064/20180227/P.nii.gz',
#    'D:/Datasets/Liver/1678064/20180227/Seg/liver.nii.gz']},
#  '1683656': {'20170626': ['D:/Datasets/Liver/1683656/20170626/A.nii.gz',
#    'D:/Datasets/Liver/1683656/20170626/D.nii.gz',
#    'D:/Datasets/Liver/1683656/20170626/label.nii.gz',
#    'D:/Datasets/Liver/1683656/20170626/P.nii.gz',
#    'D:/Datasets/Liver/1683656/20170626/Seg/liver.nii.gz']},
#  '1697539': {'20201007': ['D:/Datasets/Liver/1697539/20201007/A.nii.gz',
#    'D:/Datasets/Liver/1697539/20201007/D.nii.gz',
#    'D:/Datasets/Liver/1697539/20201007/label.nii.gz',
#    'D:/Datasets/Liver/1697539/20201007/P.nii.gz',
#    'D:/Datasets/Liver/1697539/20201007/Seg/liver.nii.gz'],
#   '20210106': ['D:/Datasets/Liver/1697539/20210106/A.nii.gz',
#    'D:/Datasets/Liver/1697539/20210106/D.nii.gz',
#    'D:/Datasets/Liver/1697539/20210106/label.nii.gz',
#    'D:/Datasets/Liver/1697539/20210106/P.nii.gz',
#    'D:/Datasets/Liver/1697539/20210106/Seg/liver.nii.gz']},
#  '1722729': {'20190208': ['D:/Datasets/Liver/1722729/20190208/A.nii.gz',
#    'D:/Datasets/Liver/1722729/20190208/D.nii.gz',
#    'D:/Datasets/Liver/1722729/20190208/label.nii.gz',
#    'D:/Datasets/Liver/1722729/20190208/P.nii.gz',
#    'D:/Datasets/Liver/1722729/20190208/Seg/liver.nii.gz'],
#   '20190325': ['D:/Datasets/Liver/1722729/20190325/A.nii.gz',
#    'D:/Datasets/Liver/1722729/20190325/D.nii.gz',
#    'D:/Datasets/Liver/1722729/20190325/label.nii.gz',
#    'D:/Datasets/Liver/1722729/20190325/P.nii.gz',
#    'D:/Datasets/Liver/1722729/20190325/Seg/liver.nii.gz']},
#  '1730325': {'20180509': ['D:/Datasets/Liver/1730325/20180509/A.nii.gz',
#    'D:/Datasets/Liver/1730325/20180509/D.nii.gz',
#    'D:/Datasets/Liver/1730325/20180509/label.nii.gz',
#    'D:/Datasets/Liver/1730325/20180509/P.nii.gz',
#    'D:/Datasets/Liver/1730325/20180509/Seg/liver.nii.gz'],
#   '20180814': ['D:/Datasets/Liver/1730325/20180814/A.nii.gz',
#    'D:/Datasets/Liver/1730325/20180814/D.nii.gz',
#    'D:/Datasets/Liver/1730325/20180814/label.nii.gz',
#    'D:/Datasets/Liver/1730325/20180814/P.nii.gz',
#    'D:/Datasets/Liver/1730325/20180814/Seg/liver.nii.gz']},
#  '1749706': {'20191004': ['D:/Datasets/Liver/1749706/20191004/A.nii.gz',
#    'D:/Datasets/Liver/1749706/20191004/D.nii.gz',
#    'D:/Datasets/Liver/1749706/20191004/label.nii.gz',
#    'D:/Datasets/Liver/1749706/20191004/P.nii.gz',
#    'D:/Datasets/Liver/1749706/20191004/Seg/liver.nii.gz'],
#   '20200514': ['D:/Datasets/Liver/1749706/20200514/A.nii.gz',
#    'D:/Datasets/Liver/1749706/20200514/D.nii.gz',
#    'D:/Datasets/Liver/1749706/20200514/label.nii.gz',
#    'D:/Datasets/Liver/1749706/20200514/P.nii.gz',
#    'D:/Datasets/Liver/1749706/20200514/Seg/liver.nii.gz']},
#  '1771939': {'20170309': ['D:/Datasets/Liver/1771939/20170309/A.nii.gz',
#    'D:/Datasets/Liver/1771939/20170309/D.nii.gz',
#    'D:/Datasets/Liver/1771939/20170309/label.nii.gz',
#    'D:/Datasets/Liver/1771939/20170309/P.nii.gz',
#    'D:/Datasets/Liver/1771939/20170309/Seg/liver.nii.gz'],
#   '20170614': ['D:/Datasets/Liver/1771939/20170614/A.nii.gz',
#    'D:/Datasets/Liver/1771939/20170614/D.nii.gz',
#    'D:/Datasets/Liver/1771939/20170614/label.nii.gz',
#    'D:/Datasets/Liver/1771939/20170614/P.nii.gz',
#    'D:/Datasets/Liver/1771939/20170614/Seg/liver.nii.gz']},
#  '1789925': {'20170525': ['D:/Datasets/Liver/1789925/20170525/A.nii.gz',
#    'D:/Datasets/Liver/1789925/20170525/D.nii.gz',
#    'D:/Datasets/Liver/1789925/20170525/label.nii.gz',
#    'D:/Datasets/Liver/1789925/20170525/P.nii.gz',
#    'D:/Datasets/Liver/1789925/20170525/Seg/liver.nii.gz']},
#  '1792405': {'20190115': ['D:/Datasets/Liver/1792405/20190115/A.nii.gz',
#    'D:/Datasets/Liver/1792405/20190115/D.nii.gz',
#    'D:/Datasets/Liver/1792405/20190115/label.nii.gz',
#    'D:/Datasets/Liver/1792405/20190115/P.nii.gz',
#    'D:/Datasets/Liver/1792405/20190115/Seg/liver.nii.gz'],
#   '20190415': ['D:/Datasets/Liver/1792405/20190415/A.nii.gz',
#    'D:/Datasets/Liver/1792405/20190415/D.nii.gz',
#    'D:/Datasets/Liver/1792405/20190415/label.nii.gz',
#    'D:/Datasets/Liver/1792405/20190415/P.nii.gz',
#    'D:/Datasets/Liver/1792405/20190415/Seg/liver.nii.gz']},
#  '1796006': {'20170110': ['D:/Datasets/Liver/1796006/20170110/A.nii.gz',
#    'D:/Datasets/Liver/1796006/20170110/D.nii.gz',
#    'D:/Datasets/Liver/1796006/20170110/label.nii.gz',
#    'D:/Datasets/Liver/1796006/20170110/P.nii.gz',
#    'D:/Datasets/Liver/1796006/20170110/Seg/liver.nii.gz'],
#   '20170801': ['D:/Datasets/Liver/1796006/20170801/A.nii.gz',
#    'D:/Datasets/Liver/1796006/20170801/D.nii.gz',
#    'D:/Datasets/Liver/1796006/20170801/label.nii.gz',
#    'D:/Datasets/Liver/1796006/20170801/P.nii.gz',
#    'D:/Datasets/Liver/1796006/20170801/Seg/liver.nii.gz']},
#  '1796041': {'20190627': ['D:/Datasets/Liver/1796041/20190627/A.nii.gz',
#    'D:/Datasets/Liver/1796041/20190627/D.nii.gz',
#    'D:/Datasets/Liver/1796041/20190627/label.nii.gz',
#    'D:/Datasets/Liver/1796041/20190627/P.nii.gz',
#    'D:/Datasets/Liver/1796041/20190627/Seg/liver.nii.gz'],
#   '20190910': ['D:/Datasets/Liver/1796041/20190910/A.nii.gz',
#    'D:/Datasets/Liver/1796041/20190910/D.nii.gz',
#    'D:/Datasets/Liver/1796041/20190910/label.nii.gz',
#    'D:/Datasets/Liver/1796041/20190910/P.nii.gz',
#    'D:/Datasets/Liver/1796041/20190910/Seg/liver.nii.gz']},
#  '1818296': {'20161012': ['D:/Datasets/Liver/1818296/20161012/A.nii.gz',
#    'D:/Datasets/Liver/1818296/20161012/D.nii.gz',
#    'D:/Datasets/Liver/1818296/20161012/label.nii.gz',
#    'D:/Datasets/Liver/1818296/20161012/P.nii.gz',
#    'D:/Datasets/Liver/1818296/20161012/Seg/liver.nii.gz'],
#   '20170118': ['D:/Datasets/Liver/1818296/20170118/A.nii.gz',
#    'D:/Datasets/Liver/1818296/20170118/D.nii.gz',
#    'D:/Datasets/Liver/1818296/20170118/label.nii.gz',
#    'D:/Datasets/Liver/1818296/20170118/P.nii.gz',
#    'D:/Datasets/Liver/1818296/20170118/Seg/liver.nii.gz']},
#  '1818656': {'20191008': ['D:/Datasets/Liver/1818656/20191008/A.nii.gz',
#    'D:/Datasets/Liver/1818656/20191008/D.nii.gz',
#    'D:/Datasets/Liver/1818656/20191008/label.nii.gz',
#    'D:/Datasets/Liver/1818656/20191008/P.nii.gz',
#    'D:/Datasets/Liver/1818656/20191008/Seg/liver.nii.gz'],
#   '20200115': ['D:/Datasets/Liver/1818656/20200115/A.nii.gz',
#    'D:/Datasets/Liver/1818656/20200115/D.nii.gz',
#    'D:/Datasets/Liver/1818656/20200115/label.nii.gz',
#    'D:/Datasets/Liver/1818656/20200115/P.nii.gz',
#    'D:/Datasets/Liver/1818656/20200115/Seg/liver.nii.gz']},
#  '1820106': {'20171204': ['D:/Datasets/Liver/1820106/20171204/A.nii.gz',
#    'D:/Datasets/Liver/1820106/20171204/D.nii.gz',
#    'D:/Datasets/Liver/1820106/20171204/label.nii.gz',
#    'D:/Datasets/Liver/1820106/20171204/P.nii.gz',
#    'D:/Datasets/Liver/1820106/20171204/Seg/liver.nii.gz'],
#   '20180320': ['D:/Datasets/Liver/1820106/20180320/A.nii.gz',
#    'D:/Datasets/Liver/1820106/20180320/D.nii.gz',
#    'D:/Datasets/Liver/1820106/20180320/label.nii.gz',
#    'D:/Datasets/Liver/1820106/20180320/P.nii.gz',
#    'D:/Datasets/Liver/1820106/20180320/Seg/liver.nii.gz']},
#  '1835380': {'20200707': ['D:/Datasets/Liver/1835380/20200707/A.nii.gz',
#    'D:/Datasets/Liver/1835380/20200707/D.nii.gz',
#    'D:/Datasets/Liver/1835380/20200707/label.nii.gz',
#    'D:/Datasets/Liver/1835380/20200707/P.nii.gz',
#    'D:/Datasets/Liver/1835380/20200707/Seg/liver.nii.gz'],
#   '20201013': ['D:/Datasets/Liver/1835380/20201013/A.nii.gz',
#    'D:/Datasets/Liver/1835380/20201013/D.nii.gz',
#    'D:/Datasets/Liver/1835380/20201013/label.nii.gz',
#    'D:/Datasets/Liver/1835380/20201013/P.nii.gz',
#    'D:/Datasets/Liver/1835380/20201013/Seg/liver.nii.gz']},
#  '1856339': {'20161213': ['D:/Datasets/Liver/1856339/20161213/A.nii.gz',
#    'D:/Datasets/Liver/1856339/20161213/D.nii.gz',
#    'D:/Datasets/Liver/1856339/20161213/label.nii.gz',
#    'D:/Datasets/Liver/1856339/20161213/P.nii.gz',
#    'D:/Datasets/Liver/1856339/20161213/Seg/liver.nii.gz'],
#   '20170531': ['D:/Datasets/Liver/1856339/20170531/A.nii.gz',
#    'D:/Datasets/Liver/1856339/20170531/D.nii.gz',
#    'D:/Datasets/Liver/1856339/20170531/label.nii.gz',
#    'D:/Datasets/Liver/1856339/20170531/P.nii.gz',
#    'D:/Datasets/Liver/1856339/20170531/Seg/liver.nii.gz']},
#  '1887239': {'20181030': ['D:/Datasets/Liver/1887239/20181030/A.nii.gz',
#    'D:/Datasets/Liver/1887239/20181030/D.nii.gz',
#    'D:/Datasets/Liver/1887239/20181030/label.nii.gz',
#    'D:/Datasets/Liver/1887239/20181030/P.nii.gz',
#    'D:/Datasets/Liver/1887239/20181030/Seg/liver.nii.gz'],
#   '20190308': ['D:/Datasets/Liver/1887239/20190308/A.nii.gz',
#    'D:/Datasets/Liver/1887239/20190308/D.nii.gz',
#    'D:/Datasets/Liver/1887239/20190308/label.nii.gz',
#    'D:/Datasets/Liver/1887239/20190308/P.nii.gz',
#    'D:/Datasets/Liver/1887239/20190308/Seg/liver.nii.gz']},
#  '1897935': {'20170309': ['D:/Datasets/Liver/1897935/20170309/A.nii.gz',
#    'D:/Datasets/Liver/1897935/20170309/D.nii.gz',
#    'D:/Datasets/Liver/1897935/20170309/label.nii.gz',
#    'D:/Datasets/Liver/1897935/20170309/P.nii.gz',
#    'D:/Datasets/Liver/1897935/20170309/Seg/liver.nii.gz']},
#  '1905250': {'20180627': ['D:/Datasets/Liver/1905250/20180627/A.nii.gz',
#    'D:/Datasets/Liver/1905250/20180627/D.nii.gz',
#    'D:/Datasets/Liver/1905250/20180627/label.nii.gz',
#    'D:/Datasets/Liver/1905250/20180627/P.nii.gz',
#    'D:/Datasets/Liver/1905250/20180627/Seg/liver.nii.gz'],
#   '20180912': ['D:/Datasets/Liver/1905250/20180912/A.nii.gz',
#    'D:/Datasets/Liver/1905250/20180912/D.nii.gz',
#    'D:/Datasets/Liver/1905250/20180912/label.nii.gz',
#    'D:/Datasets/Liver/1905250/20180912/P.nii.gz',
#    'D:/Datasets/Liver/1905250/20180912/Seg/liver.nii.gz']},
#  '1908230': {'20200728': ['D:/Datasets/Liver/1908230/20200728/A.nii.gz',
#    'D:/Datasets/Liver/1908230/20200728/D.nii.gz',
#    'D:/Datasets/Liver/1908230/20200728/label.nii.gz',
#    'D:/Datasets/Liver/1908230/20200728/P.nii.gz',
#    'D:/Datasets/Liver/1908230/20200728/Seg/liver.nii.gz']},
#  '1916005': {'20170228': ['D:/Datasets/Liver/1916005/20170228/A.nii.gz',
#    'D:/Datasets/Liver/1916005/20170228/D.nii.gz',
#    'D:/Datasets/Liver/1916005/20170228/label.nii.gz',
#    'D:/Datasets/Liver/1916005/20170228/P.nii.gz',
#    'D:/Datasets/Liver/1916005/20170228/Seg/liver.nii.gz'],
#   '20170613': ['D:/Datasets/Liver/1916005/20170613/A.nii.gz',
#    'D:/Datasets/Liver/1916005/20170613/D.nii.gz',
#    'D:/Datasets/Liver/1916005/20170613/label.nii.gz',
#    'D:/Datasets/Liver/1916005/20170613/P.nii.gz',
#    'D:/Datasets/Liver/1916005/20170613/Seg/liver.nii.gz']},
#  '1925356': {'20170704': ['D:/Datasets/Liver/1925356/20170704/A.nii.gz',
#    'D:/Datasets/Liver/1925356/20170704/D.nii.gz',
#    'D:/Datasets/Liver/1925356/20170704/label.nii.gz',
#    'D:/Datasets/Liver/1925356/20170704/P.nii.gz',
#    'D:/Datasets/Liver/1925356/20170704/Seg/liver.nii.gz'],
#   '20171011': ['D:/Datasets/Liver/1925356/20171011/A.nii.gz',
#    'D:/Datasets/Liver/1925356/20171011/D.nii.gz',
#    'D:/Datasets/Liver/1925356/20171011/label.nii.gz',
#    'D:/Datasets/Liver/1925356/20171011/P.nii.gz',
#    'D:/Datasets/Liver/1925356/20171011/Seg/liver.nii.gz']},
#  '1928501': {'20180904': ['D:/Datasets/Liver/1928501/20180904/A.nii.gz',
#    'D:/Datasets/Liver/1928501/20180904/D.nii.gz',
#    'D:/Datasets/Liver/1928501/20180904/label.nii.gz',
#    'D:/Datasets/Liver/1928501/20180904/P.nii.gz',
#    'D:/Datasets/Liver/1928501/20180904/Seg/liver.nii.gz']},
#  '1941831': {'20180131': ['D:/Datasets/Liver/1941831/20180131/A.nii.gz',
#    'D:/Datasets/Liver/1941831/20180131/D.nii.gz',
#    'D:/Datasets/Liver/1941831/20180131/label.nii.gz',
#    'D:/Datasets/Liver/1941831/20180131/P.nii.gz',
#    'D:/Datasets/Liver/1941831/20180131/Seg/liver.nii.gz'],
#   '20180511': ['D:/Datasets/Liver/1941831/20180511/A.nii.gz',
#    'D:/Datasets/Liver/1941831/20180511/D.nii.gz',
#    'D:/Datasets/Liver/1941831/20180511/label.nii.gz',
#    'D:/Datasets/Liver/1941831/20180511/P.nii.gz',
#    'D:/Datasets/Liver/1941831/20180511/Seg/liver.nii.gz']},
#  '1948297': {'20160721': ['D:/Datasets/Liver/1948297/20160721/A.nii.gz',
#    'D:/Datasets/Liver/1948297/20160721/D.nii.gz',
#    'D:/Datasets/Liver/1948297/20160721/label.nii.gz',
#    'D:/Datasets/Liver/1948297/20160721/P.nii.gz',
#    'D:/Datasets/Liver/1948297/20160721/Seg/liver.nii.gz'],
#   '20170125': ['D:/Datasets/Liver/1948297/20170125/A.nii.gz',
#    'D:/Datasets/Liver/1948297/20170125/D.nii.gz',
#    'D:/Datasets/Liver/1948297/20170125/label.nii.gz',
#    'D:/Datasets/Liver/1948297/20170125/P.nii.gz',
#    'D:/Datasets/Liver/1948297/20170125/Seg/liver.nii.gz']},
#  '1948929': {'20200819': ['D:/Datasets/Liver/1948929/20200819/A.nii.gz',
#    'D:/Datasets/Liver/1948929/20200819/D.nii.gz',
#    'D:/Datasets/Liver/1948929/20200819/label.nii.gz',
#    'D:/Datasets/Liver/1948929/20200819/P.nii.gz',
#    'D:/Datasets/Liver/1948929/20200819/Seg/liver.nii.gz'],
#   '20201216': ['D:/Datasets/Liver/1948929/20201216/A.nii.gz',
#    'D:/Datasets/Liver/1948929/20201216/D.nii.gz',
#    'D:/Datasets/Liver/1948929/20201216/label.nii.gz',
#    'D:/Datasets/Liver/1948929/20201216/P.nii.gz',
#    'D:/Datasets/Liver/1948929/20201216/Seg/liver.nii.gz']},
#  '1950805': {'20170627': ['D:/Datasets/Liver/1950805/20170627/A.nii.gz',
#    'D:/Datasets/Liver/1950805/20170627/D.nii.gz',
#    'D:/Datasets/Liver/1950805/20170627/label.nii.gz',
#    'D:/Datasets/Liver/1950805/20170627/P.nii.gz',
#    'D:/Datasets/Liver/1950805/20170627/Seg/liver.nii.gz'],
#   '20171017': ['D:/Datasets/Liver/1950805/20171017/A.nii.gz',
#    'D:/Datasets/Liver/1950805/20171017/D.nii.gz',
#    'D:/Datasets/Liver/1950805/20171017/label.nii.gz',
#    'D:/Datasets/Liver/1950805/20171017/P.nii.gz',
#    'D:/Datasets/Liver/1950805/20171017/Seg/liver.nii.gz']},
#  '1951134': {'20181012': ['D:/Datasets/Liver/1951134/20181012/A.nii.gz',
#    'D:/Datasets/Liver/1951134/20181012/D.nii.gz',
#    'D:/Datasets/Liver/1951134/20181012/label.nii.gz',
#    'D:/Datasets/Liver/1951134/20181012/P.nii.gz',
#    'D:/Datasets/Liver/1951134/20181012/Seg/liver.nii.gz'],
#   '20190327': ['D:/Datasets/Liver/1951134/20190327/A.nii.gz',
#    'D:/Datasets/Liver/1951134/20190327/D.nii.gz',
#    'D:/Datasets/Liver/1951134/20190327/label.nii.gz',
#    'D:/Datasets/Liver/1951134/20190327/P.nii.gz',
#    'D:/Datasets/Liver/1951134/20190327/Seg/liver.nii.gz']},
#  '1976550': {'20190117': ['D:/Datasets/Liver/1976550/20190117/A.nii.gz',
#    'D:/Datasets/Liver/1976550/20190117/D.nii.gz',
#    'D:/Datasets/Liver/1976550/20190117/label.nii.gz',
#    'D:/Datasets/Liver/1976550/20190117/P.nii.gz',
#    'D:/Datasets/Liver/1976550/20190117/Seg/liver.nii.gz'],
#   '20190603': ['D:/Datasets/Liver/1976550/20190603/A.nii.gz',
#    'D:/Datasets/Liver/1976550/20190603/D.nii.gz',
#    'D:/Datasets/Liver/1976550/20190603/label.nii.gz',
#    'D:/Datasets/Liver/1976550/20190603/P.nii.gz',
#    'D:/Datasets/Liver/1976550/20190603/Seg/liver.nii.gz']},
#  '1987677': {'20160831': ['D:/Datasets/Liver/1987677/20160831/A.nii.gz',
#    'D:/Datasets/Liver/1987677/20160831/D.nii.gz',
#    'D:/Datasets/Liver/1987677/20160831/label.nii.gz',
#    'D:/Datasets/Liver/1987677/20160831/P.nii.gz',
#    'D:/Datasets/Liver/1987677/20160831/Seg/liver.nii.gz'],
#   '20161207': ['D:/Datasets/Liver/1987677/20161207/A.nii.gz',
#    'D:/Datasets/Liver/1987677/20161207/D.nii.gz',
#    'D:/Datasets/Liver/1987677/20161207/label.nii.gz',
#    'D:/Datasets/Liver/1987677/20161207/P.nii.gz',
#    'D:/Datasets/Liver/1987677/20161207/Seg/liver.nii.gz']},
#  '1988190': {'20170518': ['D:/Datasets/Liver/1988190/20170518/A.nii.gz',
#    'D:/Datasets/Liver/1988190/20170518/D.nii.gz',
#    'D:/Datasets/Liver/1988190/20170518/label.nii.gz',
#    'D:/Datasets/Liver/1988190/20170518/P.nii.gz',
#    'D:/Datasets/Liver/1988190/20170518/Seg/liver.nii.gz'],
#   '20170822': ['D:/Datasets/Liver/1988190/20170822/A.nii.gz',
#    'D:/Datasets/Liver/1988190/20170822/D.nii.gz',
#    'D:/Datasets/Liver/1988190/20170822/label.nii.gz',
#    'D:/Datasets/Liver/1988190/20170822/P.nii.gz',
#    'D:/Datasets/Liver/1988190/20170822/Seg/liver.nii.gz']},
#  '1998600': {'20190821': ['D:/Datasets/Liver/1998600/20190821/A.nii.gz',
#    'D:/Datasets/Liver/1998600/20190821/D.nii.gz',
#    'D:/Datasets/Liver/1998600/20190821/label.nii.gz',
#    'D:/Datasets/Liver/1998600/20190821/P.nii.gz',
#    'D:/Datasets/Liver/1998600/20190821/Seg/liver.nii.gz'],
#   '20191217': ['D:/Datasets/Liver/1998600/20191217/A.nii.gz',
#    'D:/Datasets/Liver/1998600/20191217/D.nii.gz',
#    'D:/Datasets/Liver/1998600/20191217/label.nii.gz',
#    'D:/Datasets/Liver/1998600/20191217/P.nii.gz',
#    'D:/Datasets/Liver/1998600/20191217/Seg/liver.nii.gz']},
#  '2002367': {'20200716': ['D:/Datasets/Liver/2002367/20200716/A.nii.gz',
#    'D:/Datasets/Liver/2002367/20200716/D.nii.gz',
#    'D:/Datasets/Liver/2002367/20200716/label.nii.gz',
#    'D:/Datasets/Liver/2002367/20200716/P.nii.gz',
#    'D:/Datasets/Liver/2002367/20200716/Seg/liver.nii.gz']},
#  '2007189': {'20200625': ['D:/Datasets/Liver/2007189/20200625/A.nii.gz',
#    'D:/Datasets/Liver/2007189/20200625/D.nii.gz',
#    'D:/Datasets/Liver/2007189/20200625/label.nii.gz',
#    'D:/Datasets/Liver/2007189/20200625/P.nii.gz',
#    'D:/Datasets/Liver/2007189/20200625/Seg/liver.nii.gz'],
#   '20200914': ['D:/Datasets/Liver/2007189/20200914/A.nii.gz',
#    'D:/Datasets/Liver/2007189/20200914/D.nii.gz',
#    'D:/Datasets/Liver/2007189/20200914/label.nii.gz',
#    'D:/Datasets/Liver/2007189/20200914/P.nii.gz',
#    'D:/Datasets/Liver/2007189/20200914/Seg/liver.nii.gz']},
#  '2016451': {'20180928': ['D:/Datasets/Liver/2016451/20180928/A.nii.gz',
#    'D:/Datasets/Liver/2016451/20180928/D.nii.gz',
#    'D:/Datasets/Liver/2016451/20180928/label.nii.gz',
#    'D:/Datasets/Liver/2016451/20180928/P.nii.gz',
#    'D:/Datasets/Liver/2016451/20180928/Seg/liver.nii.gz'],
#   '20190103': ['D:/Datasets/Liver/2016451/20190103/A.nii.gz',
#    'D:/Datasets/Liver/2016451/20190103/D.nii.gz',
#    'D:/Datasets/Liver/2016451/20190103/label.nii.gz',
#    'D:/Datasets/Liver/2016451/20190103/P.nii.gz',
#    'D:/Datasets/Liver/2016451/20190103/Seg/liver.nii.gz']},
#  '2034277': {'20180209': ['D:/Datasets/Liver/2034277/20180209/A.nii.gz',
#    'D:/Datasets/Liver/2034277/20180209/D.nii.gz',
#    'D:/Datasets/Liver/2034277/20180209/label.nii.gz',
#    'D:/Datasets/Liver/2034277/20180209/P.nii.gz',
#    'D:/Datasets/Liver/2034277/20180209/Seg/liver.nii.gz'],
#   '20180517': ['D:/Datasets/Liver/2034277/20180517/A.nii.gz',
#    'D:/Datasets/Liver/2034277/20180517/D.nii.gz',
#    'D:/Datasets/Liver/2034277/20180517/label.nii.gz',
#    'D:/Datasets/Liver/2034277/20180517/P.nii.gz',
#    'D:/Datasets/Liver/2034277/20180517/Seg/liver.nii.gz']},
#  '2035474': {'20190527': ['D:/Datasets/Liver/2035474/20190527/A.nii.gz',
#    'D:/Datasets/Liver/2035474/20190527/D.nii.gz',
#    'D:/Datasets/Liver/2035474/20190527/label.nii.gz',
#    'D:/Datasets/Liver/2035474/20190527/P.nii.gz',
#    'D:/Datasets/Liver/2035474/20190527/Seg/liver.nii.gz'],
#   '20190903': ['D:/Datasets/Liver/2035474/20190903/A.nii.gz',
#    'D:/Datasets/Liver/2035474/20190903/D.nii.gz',
#    'D:/Datasets/Liver/2035474/20190903/label.nii.gz',
#    'D:/Datasets/Liver/2035474/20190903/P.nii.gz',
#    'D:/Datasets/Liver/2035474/20190903/Seg/liver.nii.gz']},
#  '2047878': {'20170322': ['D:/Datasets/Liver/2047878/20170322/A.nii.gz',
#    'D:/Datasets/Liver/2047878/20170322/D.nii.gz',
#    'D:/Datasets/Liver/2047878/20170322/label.nii.gz',
#    'D:/Datasets/Liver/2047878/20170322/P.nii.gz',
#    'D:/Datasets/Liver/2047878/20170322/Seg/liver.nii.gz']},
#  '2051653': {'20170208': ['D:/Datasets/Liver/2051653/20170208/A.nii.gz',
#    'D:/Datasets/Liver/2051653/20170208/D.nii.gz',
#    'D:/Datasets/Liver/2051653/20170208/label.nii.gz',
#    'D:/Datasets/Liver/2051653/20170208/P.nii.gz',
#    'D:/Datasets/Liver/2051653/20170208/Seg/liver.nii.gz']},
#  '2053326': {'20180827': ['D:/Datasets/Liver/2053326/20180827/A.nii.gz',
#    'D:/Datasets/Liver/2053326/20180827/D.nii.gz',
#    'D:/Datasets/Liver/2053326/20180827/label.nii.gz',
#    'D:/Datasets/Liver/2053326/20180827/P.nii.gz',
#    'D:/Datasets/Liver/2053326/20180827/Seg/liver.nii.gz'],
#   '20181127': ['D:/Datasets/Liver/2053326/20181127/A.nii.gz',
#    'D:/Datasets/Liver/2053326/20181127/D.nii.gz',
#    'D:/Datasets/Liver/2053326/20181127/label.nii.gz',
#    'D:/Datasets/Liver/2053326/20181127/P.nii.gz',
#    'D:/Datasets/Liver/2053326/20181127/Seg/liver.nii.gz']},
#  '2057525': {'20170912': ['D:/Datasets/Liver/2057525/20170912/A.nii.gz',
#    'D:/Datasets/Liver/2057525/20170912/D.nii.gz',
#    'D:/Datasets/Liver/2057525/20170912/label.nii.gz',
#    'D:/Datasets/Liver/2057525/20170912/P.nii.gz',
#    'D:/Datasets/Liver/2057525/20170912/Seg/liver.nii.gz'],
#   '20180109': ['D:/Datasets/Liver/2057525/20180109/A.nii.gz',
#    'D:/Datasets/Liver/2057525/20180109/D.nii.gz',
#    'D:/Datasets/Liver/2057525/20180109/label.nii.gz',
#    'D:/Datasets/Liver/2057525/20180109/P.nii.gz',
#    'D:/Datasets/Liver/2057525/20180109/Seg/liver.nii.gz']},
#  '2070066': {'20170123': ['D:/Datasets/Liver/2070066/20170123/A.nii.gz',
#    'D:/Datasets/Liver/2070066/20170123/D.nii.gz',
#    'D:/Datasets/Liver/2070066/20170123/label.nii.gz',
#    'D:/Datasets/Liver/2070066/20170123/P.nii.gz',
#    'D:/Datasets/Liver/2070066/20170123/Seg/liver.nii.gz'],
#   '20170522': ['D:/Datasets/Liver/2070066/20170522/A.nii.gz',
#    'D:/Datasets/Liver/2070066/20170522/D.nii.gz',
#    'D:/Datasets/Liver/2070066/20170522/label.nii.gz',
#    'D:/Datasets/Liver/2070066/20170522/P.nii.gz',
#    'D:/Datasets/Liver/2070066/20170522/Seg/liver.nii.gz']},
#  '2072556': {'20180131': ['D:/Datasets/Liver/2072556/20180131/A.nii.gz',
#    'D:/Datasets/Liver/2072556/20180131/D.nii.gz',
#    'D:/Datasets/Liver/2072556/20180131/label.nii.gz',
#    'D:/Datasets/Liver/2072556/20180131/P.nii.gz',
#    'D:/Datasets/Liver/2072556/20180131/Seg/liver.nii.gz'],
#   '20180716': ['D:/Datasets/Liver/2072556/20180716/A.nii.gz',
#    'D:/Datasets/Liver/2072556/20180716/D.nii.gz',
#    'D:/Datasets/Liver/2072556/20180716/label.nii.gz',
#    'D:/Datasets/Liver/2072556/20180716/P.nii.gz',
#    'D:/Datasets/Liver/2072556/20180716/Seg/liver.nii.gz']},
#  '2086068': {'20181213': ['D:/Datasets/Liver/2086068/20181213/A.nii.gz',
#    'D:/Datasets/Liver/2086068/20181213/D.nii.gz',
#    'D:/Datasets/Liver/2086068/20181213/label.nii.gz',
#    'D:/Datasets/Liver/2086068/20181213/P.nii.gz',
#    'D:/Datasets/Liver/2086068/20181213/Seg/liver.nii.gz'],
#   '20190207': ['D:/Datasets/Liver/2086068/20190207/A.nii.gz',
#    'D:/Datasets/Liver/2086068/20190207/D.nii.gz',
#    'D:/Datasets/Liver/2086068/20190207/label.nii.gz',
#    'D:/Datasets/Liver/2086068/20190207/P.nii.gz',
#    'D:/Datasets/Liver/2086068/20190207/Seg/liver.nii.gz']},
#  '2095499': {'20190213': ['D:/Datasets/Liver/2095499/20190213/A.nii.gz',
#    'D:/Datasets/Liver/2095499/20190213/D.nii.gz',
#    'D:/Datasets/Liver/2095499/20190213/label.nii.gz',
#    'D:/Datasets/Liver/2095499/20190213/P.nii.gz',
#    'D:/Datasets/Liver/2095499/20190213/Seg/liver.nii.gz'],
#   '20190904': ['D:/Datasets/Liver/2095499/20190904/A.nii.gz',
#    'D:/Datasets/Liver/2095499/20190904/D.nii.gz',
#    'D:/Datasets/Liver/2095499/20190904/label.nii.gz',
#    'D:/Datasets/Liver/2095499/20190904/P.nii.gz',
#    'D:/Datasets/Liver/2095499/20190904/Seg/liver.nii.gz']},
#  '2107188': {'20180214': ['D:/Datasets/Liver/2107188/20180214/A.nii.gz',
#    'D:/Datasets/Liver/2107188/20180214/D.nii.gz',
#    'D:/Datasets/Liver/2107188/20180214/label.nii.gz',
#    'D:/Datasets/Liver/2107188/20180214/P.nii.gz',
#    'D:/Datasets/Liver/2107188/20180214/Seg/liver.nii.gz'],
#   '20180628': ['D:/Datasets/Liver/2107188/20180628/A.nii.gz',
#    'D:/Datasets/Liver/2107188/20180628/D.nii.gz',
#    'D:/Datasets/Liver/2107188/20180628/label.nii.gz',
#    'D:/Datasets/Liver/2107188/20180628/P.nii.gz',
#    'D:/Datasets/Liver/2107188/20180628/Seg/liver.nii.gz']},
#  '2111111': {'20200108': ['D:/Datasets/Liver/2111111/20200108/A.nii.gz',
#    'D:/Datasets/Liver/2111111/20200108/D.nii.gz',
#    'D:/Datasets/Liver/2111111/20200108/label.nii.gz',
#    'D:/Datasets/Liver/2111111/20200108/P.nii.gz',
#    'D:/Datasets/Liver/2111111/20200108/Seg/liver.nii.gz'],
#   '20200916': ['D:/Datasets/Liver/2111111/20200916/A.nii.gz',
#    'D:/Datasets/Liver/2111111/20200916/D.nii.gz',
#    'D:/Datasets/Liver/2111111/20200916/label.nii.gz',
#    'D:/Datasets/Liver/2111111/20200916/P.nii.gz',
#    'D:/Datasets/Liver/2111111/20200916/Seg/liver.nii.gz']},
#  '2118104': {'20160921': ['D:/Datasets/Liver/2118104/20160921/A.nii.gz',
#    'D:/Datasets/Liver/2118104/20160921/D.nii.gz',
#    'D:/Datasets/Liver/2118104/20160921/label.nii.gz',
#    'D:/Datasets/Liver/2118104/20160921/P.nii.gz',
#    'D:/Datasets/Liver/2118104/20160921/Seg/liver.nii.gz'],
#   '20170426': ['D:/Datasets/Liver/2118104/20170426/A.nii.gz',
#    'D:/Datasets/Liver/2118104/20170426/D.nii.gz',
#    'D:/Datasets/Liver/2118104/20170426/label.nii.gz',
#    'D:/Datasets/Liver/2118104/20170426/P.nii.gz',
#    'D:/Datasets/Liver/2118104/20170426/Seg/liver.nii.gz']},
#  '2136740': {'20161025': ['D:/Datasets/Liver/2136740/20161025/A.nii.gz',
#    'D:/Datasets/Liver/2136740/20161025/D.nii.gz',
#    'D:/Datasets/Liver/2136740/20161025/label.nii.gz',
#    'D:/Datasets/Liver/2136740/20161025/P.nii.gz',
#    'D:/Datasets/Liver/2136740/20161025/Seg/liver.nii.gz'],
#   '20170511': ['D:/Datasets/Liver/2136740/20170511/A.nii.gz',
#    'D:/Datasets/Liver/2136740/20170511/D.nii.gz',
#    'D:/Datasets/Liver/2136740/20170511/label.nii.gz',
#    'D:/Datasets/Liver/2136740/20170511/P.nii.gz',
#    'D:/Datasets/Liver/2136740/20170511/Seg/liver.nii.gz']},
#  '2144375': {'20170926': ['D:/Datasets/Liver/2144375/20170926/A.nii.gz',
#    'D:/Datasets/Liver/2144375/20170926/D.nii.gz',
#    'D:/Datasets/Liver/2144375/20170926/label.nii.gz',
#    'D:/Datasets/Liver/2144375/20170926/P.nii.gz',
#    'D:/Datasets/Liver/2144375/20170926/Seg/liver.nii.gz'],
#   '20180102': ['D:/Datasets/Liver/2144375/20180102/A.nii.gz',
#    'D:/Datasets/Liver/2144375/20180102/D.nii.gz',
#    'D:/Datasets/Liver/2144375/20180102/label.nii.gz',
#    'D:/Datasets/Liver/2144375/20180102/P.nii.gz',
#    'D:/Datasets/Liver/2144375/20180102/Seg/liver.nii.gz']},
#  '2146539': {'20160907': ['D:/Datasets/Liver/2146539/20160907/A.nii.gz',
#    'D:/Datasets/Liver/2146539/20160907/D.nii.gz',
#    'D:/Datasets/Liver/2146539/20160907/label.nii.gz',
#    'D:/Datasets/Liver/2146539/20160907/P.nii.gz',
#    'D:/Datasets/Liver/2146539/20160907/Seg/liver.nii.gz'],
#   '20161221': ['D:/Datasets/Liver/2146539/20161221/A.nii.gz',
#    'D:/Datasets/Liver/2146539/20161221/D.nii.gz',
#    'D:/Datasets/Liver/2146539/20161221/label.nii.gz',
#    'D:/Datasets/Liver/2146539/20161221/P.nii.gz',
#    'D:/Datasets/Liver/2146539/20161221/Seg/liver.nii.gz']},
#  '2156207': {'20181214': ['D:/Datasets/Liver/2156207/20181214/A.nii.gz',
#    'D:/Datasets/Liver/2156207/20181214/D.nii.gz',
#    'D:/Datasets/Liver/2156207/20181214/label.nii.gz',
#    'D:/Datasets/Liver/2156207/20181214/P.nii.gz',
#    'D:/Datasets/Liver/2156207/20181214/Seg/liver.nii.gz'],
#   '20190314': ['D:/Datasets/Liver/2156207/20190314/A.nii.gz',
#    'D:/Datasets/Liver/2156207/20190314/D.nii.gz',
#    'D:/Datasets/Liver/2156207/20190314/label.nii.gz',
#    'D:/Datasets/Liver/2156207/20190314/P.nii.gz',
#    'D:/Datasets/Liver/2156207/20190314/Seg/liver.nii.gz']},
#  '2181265': {'20200731': ['D:/Datasets/Liver/2181265/20200731/A.nii.gz',
#    'D:/Datasets/Liver/2181265/20200731/D.nii.gz',
#    'D:/Datasets/Liver/2181265/20200731/label.nii.gz',
#    'D:/Datasets/Liver/2181265/20200731/P.nii.gz',
#    'D:/Datasets/Liver/2181265/20200731/Seg/liver.nii.gz'],
#   '20201109': ['D:/Datasets/Liver/2181265/20201109/A.nii.gz',
#    'D:/Datasets/Liver/2181265/20201109/D.nii.gz',
#    'D:/Datasets/Liver/2181265/20201109/label.nii.gz',
#    'D:/Datasets/Liver/2181265/20201109/P.nii.gz',
#    'D:/Datasets/Liver/2181265/20201109/Seg/liver.nii.gz']},
#  '2190539': {'20190515': ['D:/Datasets/Liver/2190539/20190515/A.nii.gz',
#    'D:/Datasets/Liver/2190539/20190515/D.nii.gz',
#    'D:/Datasets/Liver/2190539/20190515/label.nii.gz',
#    'D:/Datasets/Liver/2190539/20190515/P.nii.gz',
#    'D:/Datasets/Liver/2190539/20190515/Seg/liver.nii.gz'],
#   '20190813': ['D:/Datasets/Liver/2190539/20190813/A.nii.gz',
#    'D:/Datasets/Liver/2190539/20190813/D.nii.gz',
#    'D:/Datasets/Liver/2190539/20190813/label.nii.gz',
#    'D:/Datasets/Liver/2190539/20190813/P.nii.gz',
#    'D:/Datasets/Liver/2190539/20190813/Seg/liver.nii.gz']},
#  '2199671': {'20180227': ['D:/Datasets/Liver/2199671/20180227/A.nii.gz',
#    'D:/Datasets/Liver/2199671/20180227/D.nii.gz',
#    'D:/Datasets/Liver/2199671/20180227/label.nii.gz',
#    'D:/Datasets/Liver/2199671/20180227/P.nii.gz',
#    'D:/Datasets/Liver/2199671/20180227/Seg/liver.nii.gz'],
#   '20180529': ['D:/Datasets/Liver/2199671/20180529/A.nii.gz',
#    'D:/Datasets/Liver/2199671/20180529/D.nii.gz',
#    'D:/Datasets/Liver/2199671/20180529/label.nii.gz',
#    'D:/Datasets/Liver/2199671/20180529/P.nii.gz',
#    'D:/Datasets/Liver/2199671/20180529/Seg/liver.nii.gz']},
#  '2206340': {'20170907': ['D:/Datasets/Liver/2206340/20170907/A.nii.gz',
#    'D:/Datasets/Liver/2206340/20170907/D.nii.gz',
#    'D:/Datasets/Liver/2206340/20170907/label.nii.gz',
#    'D:/Datasets/Liver/2206340/20170907/P.nii.gz',
#    'D:/Datasets/Liver/2206340/20170907/Seg/liver.nii.gz'],
#   '20171123': ['D:/Datasets/Liver/2206340/20171123/A.nii.gz',
#    'D:/Datasets/Liver/2206340/20171123/D.nii.gz',
#    'D:/Datasets/Liver/2206340/20171123/label.nii.gz',
#    'D:/Datasets/Liver/2206340/20171123/P.nii.gz',
#    'D:/Datasets/Liver/2206340/20171123/Seg/liver.nii.gz']},
#  '2225752': {'20170524': ['D:/Datasets/Liver/2225752/20170524/A.nii.gz',
#    'D:/Datasets/Liver/2225752/20170524/D.nii.gz',
#    'D:/Datasets/Liver/2225752/20170524/label.nii.gz',
#    'D:/Datasets/Liver/2225752/20170524/P.nii.gz',
#    'D:/Datasets/Liver/2225752/20170524/Seg/liver.nii.gz'],
#   '20171025': ['D:/Datasets/Liver/2225752/20171025/A.nii.gz',
#    'D:/Datasets/Liver/2225752/20171025/D.nii.gz',
#    'D:/Datasets/Liver/2225752/20171025/label.nii.gz',
#    'D:/Datasets/Liver/2225752/20171025/P.nii.gz',
#    'D:/Datasets/Liver/2225752/20171025/Seg/liver.nii.gz']},
#  '2232848': {'20161011': ['D:/Datasets/Liver/2232848/20161011/A.nii.gz',
#    'D:/Datasets/Liver/2232848/20161011/D.nii.gz',
#    'D:/Datasets/Liver/2232848/20161011/label.nii.gz',
#    'D:/Datasets/Liver/2232848/20161011/P.nii.gz',
#    'D:/Datasets/Liver/2232848/20161011/Seg/liver.nii.gz'],
#   '20170117': ['D:/Datasets/Liver/2232848/20170117/A.nii.gz',
#    'D:/Datasets/Liver/2232848/20170117/D.nii.gz',
#    'D:/Datasets/Liver/2232848/20170117/label.nii.gz',
#    'D:/Datasets/Liver/2232848/20170117/P.nii.gz',
#    'D:/Datasets/Liver/2232848/20170117/Seg/liver.nii.gz']},
#  '2235007': {'20180417': ['D:/Datasets/Liver/2235007/20180417/A.nii.gz',
#    'D:/Datasets/Liver/2235007/20180417/D.nii.gz',
#    'D:/Datasets/Liver/2235007/20180417/label.nii.gz',
#    'D:/Datasets/Liver/2235007/20180417/P.nii.gz',
#    'D:/Datasets/Liver/2235007/20180417/Seg/liver.nii.gz'],
#   '20180716': ['D:/Datasets/Liver/2235007/20180716/A.nii.gz',
#    'D:/Datasets/Liver/2235007/20180716/D.nii.gz',
#    'D:/Datasets/Liver/2235007/20180716/label.nii.gz',
#    'D:/Datasets/Liver/2235007/20180716/P.nii.gz',
#    'D:/Datasets/Liver/2235007/20180716/Seg/liver.nii.gz']},
#  '2252831': {'20190109': ['D:/Datasets/Liver/2252831/20190109/A.nii.gz',
#    'D:/Datasets/Liver/2252831/20190109/D.nii.gz',
#    'D:/Datasets/Liver/2252831/20190109/label.nii.gz',
#    'D:/Datasets/Liver/2252831/20190109/P.nii.gz',
#    'D:/Datasets/Liver/2252831/20190109/Seg/liver.nii.gz'],
#   '20190709': ['D:/Datasets/Liver/2252831/20190709/A.nii.gz',
#    'D:/Datasets/Liver/2252831/20190709/D.nii.gz',
# ...
#    'D:/Datasets/Liver/7077430/20171227/Seg/liver.nii.gz']},
#  '7078821': {'20170621': ['D:/Datasets/Liver/7078821/20170621/A.nii.gz',
#    'D:/Datasets/Liver/7078821/20170621/D.nii.gz',
#    'D:/Datasets/Liver/7078821/20170621/label.nii.gz',
#    'D:/Datasets/Liver/7078821/20170621/P.nii.gz',
#    'D:/Datasets/Liver/7078821/20170621/Seg/liver.nii.gz'],
#   '20170927': ['D:/Datasets/Liver/7078821/20170927/A.nii.gz',
#    'D:/Datasets/Liver/7078821/20170927/D.nii.gz',
#    'D:/Datasets/Liver/7078821/20170927/label.nii.gz',
#    'D:/Datasets/Liver/7078821/20170927/P.nii.gz',
#    'D:/Datasets/Liver/7078821/20170927/Seg/liver.nii.gz']},
#  '7083955': {'20160713': ['D:/Datasets/Liver/7083955/20160713/A.nii.gz',
#    'D:/Datasets/Liver/7083955/20160713/D.nii.gz',
#    'D:/Datasets/Liver/7083955/20160713/label.nii.gz',
#    'D:/Datasets/Liver/7083955/20160713/P.nii.gz',
#    'D:/Datasets/Liver/7083955/20160713/Seg/liver.nii.gz'],
#   '20161005': ['D:/Datasets/Liver/7083955/20161005/A.nii.gz',
#    'D:/Datasets/Liver/7083955/20161005/D.nii.gz',
#    'D:/Datasets/Liver/7083955/20161005/label.nii.gz',
#    'D:/Datasets/Liver/7083955/20161005/P.nii.gz',
#    'D:/Datasets/Liver/7083955/20161005/Seg/liver.nii.gz'],
#   '20170109': ['D:/Datasets/Liver/7083955/20170109/A.nii.gz',
#    'D:/Datasets/Liver/7083955/20170109/D.nii.gz',
#    'D:/Datasets/Liver/7083955/20170109/label.nii.gz',
#    'D:/Datasets/Liver/7083955/20170109/P.nii.gz',
#    'D:/Datasets/Liver/7083955/20170109/Seg/liver.nii.gz'],
#   '20170920': ['D:/Datasets/Liver/7083955/20170920/A.nii.gz',
#    'D:/Datasets/Liver/7083955/20170920/D.nii.gz',
#    'D:/Datasets/Liver/7083955/20170920/label.nii.gz',
#    'D:/Datasets/Liver/7083955/20170920/P.nii.gz',
#    'D:/Datasets/Liver/7083955/20170920/Seg/liver.nii.gz'],
#   '20171219': ['D:/Datasets/Liver/7083955/20171219/A.nii.gz',
#    'D:/Datasets/Liver/7083955/20171219/D.nii.gz',
#    'D:/Datasets/Liver/7083955/20171219/label.nii.gz',
#    'D:/Datasets/Liver/7083955/20171219/P.nii.gz',
#    'D:/Datasets/Liver/7083955/20171219/Seg/liver.nii.gz']},
#  '7088146': {'20171011': ['D:/Datasets/Liver/7088146/20171011/A.nii.gz',
#    'D:/Datasets/Liver/7088146/20171011/D.nii.gz',
#    'D:/Datasets/Liver/7088146/20171011/label.nii.gz',
#    'D:/Datasets/Liver/7088146/20171011/P.nii.gz',
#    'D:/Datasets/Liver/7088146/20171011/Seg/liver.nii.gz'],
#   '20180219': ['D:/Datasets/Liver/7088146/20180219/A.nii.gz',
#    'D:/Datasets/Liver/7088146/20180219/D.nii.gz',
#    'D:/Datasets/Liver/7088146/20180219/label.nii.gz',
#    'D:/Datasets/Liver/7088146/20180219/P.nii.gz',
#    'D:/Datasets/Liver/7088146/20180219/Seg/liver.nii.gz']},
#  '7088634': {'20161109': ['D:/Datasets/Liver/7088634/20161109/A.nii.gz',
#    'D:/Datasets/Liver/7088634/20161109/D.nii.gz',
#    'D:/Datasets/Liver/7088634/20161109/label.nii.gz',
#    'D:/Datasets/Liver/7088634/20161109/P.nii.gz',
#    'D:/Datasets/Liver/7088634/20161109/Seg/liver.nii.gz'],
#   '20170215': ['D:/Datasets/Liver/7088634/20170215/A.nii.gz',
#    'D:/Datasets/Liver/7088634/20170215/D.nii.gz',
#    'D:/Datasets/Liver/7088634/20170215/label.nii.gz',
#    'D:/Datasets/Liver/7088634/20170215/P.nii.gz',
#    'D:/Datasets/Liver/7088634/20170215/Seg/liver.nii.gz'],
#   '20170515': ['D:/Datasets/Liver/7088634/20170515/A.nii.gz',
#    'D:/Datasets/Liver/7088634/20170515/D.nii.gz',
#    'D:/Datasets/Liver/7088634/20170515/label.nii.gz',
#    'D:/Datasets/Liver/7088634/20170515/P.nii.gz',
#    'D:/Datasets/Liver/7088634/20170515/Seg/liver.nii.gz']},
#  '7092179': {'20171122': ['D:/Datasets/Liver/7092179/20171122/A.nii.gz',
#    'D:/Datasets/Liver/7092179/20171122/D.nii.gz',
#    'D:/Datasets/Liver/7092179/20171122/label.nii.gz',
#    'D:/Datasets/Liver/7092179/20171122/P.nii.gz',
#    'D:/Datasets/Liver/7092179/20171122/Seg/liver.nii.gz'],
#   '20180420': ['D:/Datasets/Liver/7092179/20180420/A.nii.gz',
#    'D:/Datasets/Liver/7092179/20180420/D.nii.gz',
#    'D:/Datasets/Liver/7092179/20180420/label.nii.gz',
#    'D:/Datasets/Liver/7092179/20180420/P.nii.gz',
#    'D:/Datasets/Liver/7092179/20180420/Seg/liver.nii.gz'],
#   '20180612': ['D:/Datasets/Liver/7092179/20180612/A.nii.gz',
#    'D:/Datasets/Liver/7092179/20180612/D.nii.gz',
#    'D:/Datasets/Liver/7092179/20180612/label.nii.gz',
#    'D:/Datasets/Liver/7092179/20180612/P.nii.gz',
#    'D:/Datasets/Liver/7092179/20180612/Seg/liver.nii.gz']},
#  '7094285': {'20180402': ['D:/Datasets/Liver/7094285/20180402/A.nii.gz',
#    'D:/Datasets/Liver/7094285/20180402/D.nii.gz',
#    'D:/Datasets/Liver/7094285/20180402/label.nii.gz',
#    'D:/Datasets/Liver/7094285/20180402/P.nii.gz',
#    'D:/Datasets/Liver/7094285/20180402/Seg/liver.nii.gz'],
#   '20180716': ['D:/Datasets/Liver/7094285/20180716/A.nii.gz',
#    'D:/Datasets/Liver/7094285/20180716/D.nii.gz',
#    'D:/Datasets/Liver/7094285/20180716/label.nii.gz',
#    'D:/Datasets/Liver/7094285/20180716/P.nii.gz',
#    'D:/Datasets/Liver/7094285/20180716/Seg/liver.nii.gz'],
#   '20181015': ['D:/Datasets/Liver/7094285/20181015/A.nii.gz',
#    'D:/Datasets/Liver/7094285/20181015/D.nii.gz',
#    'D:/Datasets/Liver/7094285/20181015/label.nii.gz',
#    'D:/Datasets/Liver/7094285/20181015/P.nii.gz',
#    'D:/Datasets/Liver/7094285/20181015/Seg/liver.nii.gz']},
#  '7094726': {'20170102': ['D:/Datasets/Liver/7094726/20170102/A.nii.gz',
#    'D:/Datasets/Liver/7094726/20170102/D.nii.gz',
#    'D:/Datasets/Liver/7094726/20170102/label.nii.gz',
#    'D:/Datasets/Liver/7094726/20170102/P.nii.gz',
#    'D:/Datasets/Liver/7094726/20170102/Seg/liver.nii.gz'],
#   '20180718': ['D:/Datasets/Liver/7094726/20180718/A.nii.gz',
#    'D:/Datasets/Liver/7094726/20180718/D.nii.gz',
#    'D:/Datasets/Liver/7094726/20180718/label.nii.gz',
#    'D:/Datasets/Liver/7094726/20180718/P.nii.gz',
#    'D:/Datasets/Liver/7094726/20180718/Seg/liver.nii.gz'],
#   '20181031': ['D:/Datasets/Liver/7094726/20181031/A.nii.gz',
#    'D:/Datasets/Liver/7094726/20181031/D.nii.gz',
#    'D:/Datasets/Liver/7094726/20181031/label.nii.gz',
#    'D:/Datasets/Liver/7094726/20181031/P.nii.gz',
#    'D:/Datasets/Liver/7094726/20181031/Seg/liver.nii.gz'],
#   '20201028': ['D:/Datasets/Liver/7094726/20201028/A.nii.gz',
#    'D:/Datasets/Liver/7094726/20201028/D.nii.gz',
#    'D:/Datasets/Liver/7094726/20201028/label.nii.gz',
#    'D:/Datasets/Liver/7094726/20201028/P.nii.gz',
#    'D:/Datasets/Liver/7094726/20201028/Seg/liver.nii.gz']},
#  '7096174': {'20180102': ['D:/Datasets/Liver/7096174/20180102/A.nii.gz',
#    'D:/Datasets/Liver/7096174/20180102/D.nii.gz',
#    'D:/Datasets/Liver/7096174/20180102/label.nii.gz',
#    'D:/Datasets/Liver/7096174/20180102/P.nii.gz',
#    'D:/Datasets/Liver/7096174/20180102/Seg/liver.nii.gz'],
#   '20180327': ['D:/Datasets/Liver/7096174/20180327/A.nii.gz',
#    'D:/Datasets/Liver/7096174/20180327/D.nii.gz',
#    'D:/Datasets/Liver/7096174/20180327/label.nii.gz',
#    'D:/Datasets/Liver/7096174/20180327/P.nii.gz',
#    'D:/Datasets/Liver/7096174/20180327/Seg/liver.nii.gz'],
#   '20180619': ['D:/Datasets/Liver/7096174/20180619/A.nii.gz',
#    'D:/Datasets/Liver/7096174/20180619/D.nii.gz',
#    'D:/Datasets/Liver/7096174/20180619/label.nii.gz',
#    'D:/Datasets/Liver/7096174/20180619/P.nii.gz',
#    'D:/Datasets/Liver/7096174/20180619/Seg/liver.nii.gz']},
#  '7096636': {'20190515': ['D:/Datasets/Liver/7096636/20190515/A.nii.gz',
#    'D:/Datasets/Liver/7096636/20190515/D.nii.gz',
#    'D:/Datasets/Liver/7096636/20190515/label.nii.gz',
#    'D:/Datasets/Liver/7096636/20190515/P.nii.gz',
#    'D:/Datasets/Liver/7096636/20190515/Seg/liver.nii.gz'],
#   '20190814': ['D:/Datasets/Liver/7096636/20190814/A.nii.gz',
#    'D:/Datasets/Liver/7096636/20190814/D.nii.gz',
#    'D:/Datasets/Liver/7096636/20190814/label.nii.gz',
#    'D:/Datasets/Liver/7096636/20190814/P.nii.gz',
#    'D:/Datasets/Liver/7096636/20190814/Seg/liver.nii.gz'],
#   '20191114': ['D:/Datasets/Liver/7096636/20191114/A.nii.gz',
#    'D:/Datasets/Liver/7096636/20191114/D.nii.gz',
#    'D:/Datasets/Liver/7096636/20191114/label.nii.gz',
#    'D:/Datasets/Liver/7096636/20191114/P.nii.gz',
#    'D:/Datasets/Liver/7096636/20191114/Seg/liver.nii.gz']},
#  '7097124': {'20181002': ['D:/Datasets/Liver/7097124/20181002/A.nii.gz',
#    'D:/Datasets/Liver/7097124/20181002/D.nii.gz',
#    'D:/Datasets/Liver/7097124/20181002/label.nii.gz',
#    'D:/Datasets/Liver/7097124/20181002/P.nii.gz',
#    'D:/Datasets/Liver/7097124/20181002/Seg/liver.nii.gz'],
#   '20190108': ['D:/Datasets/Liver/7097124/20190108/A.nii.gz',
#    'D:/Datasets/Liver/7097124/20190108/D.nii.gz',
#    'D:/Datasets/Liver/7097124/20190108/label.nii.gz',
#    'D:/Datasets/Liver/7097124/20190108/P.nii.gz',
#    'D:/Datasets/Liver/7097124/20190108/Seg/liver.nii.gz']},
#  '7113113': {'20161130': ['D:/Datasets/Liver/7113113/20161130/A.nii.gz',
#    'D:/Datasets/Liver/7113113/20161130/D.nii.gz',
#    'D:/Datasets/Liver/7113113/20161130/label.nii.gz',
#    'D:/Datasets/Liver/7113113/20161130/P.nii.gz',
#    'D:/Datasets/Liver/7113113/20161130/Seg/liver.nii.gz'],
#   '20170327': ['D:/Datasets/Liver/7113113/20170327/A.nii.gz',
#    'D:/Datasets/Liver/7113113/20170327/D.nii.gz',
#    'D:/Datasets/Liver/7113113/20170327/label.nii.gz',
#    'D:/Datasets/Liver/7113113/20170327/P.nii.gz',
#    'D:/Datasets/Liver/7113113/20170327/Seg/liver.nii.gz'],
#   '20170915': ['D:/Datasets/Liver/7113113/20170915/A.nii.gz',
#    'D:/Datasets/Liver/7113113/20170915/D.nii.gz',
#    'D:/Datasets/Liver/7113113/20170915/label.nii.gz',
#    'D:/Datasets/Liver/7113113/20170915/P.nii.gz',
#    'D:/Datasets/Liver/7113113/20170915/Seg/liver.nii.gz']},
#  '7115793': {'20171023': ['D:/Datasets/Liver/7115793/20171023/A.nii.gz',
#    'D:/Datasets/Liver/7115793/20171023/D.nii.gz',
#    'D:/Datasets/Liver/7115793/20171023/label.nii.gz',
#    'D:/Datasets/Liver/7115793/20171023/P.nii.gz',
#    'D:/Datasets/Liver/7115793/20171023/Seg/liver.nii.gz'],
#   '20180222': ['D:/Datasets/Liver/7115793/20180222/A.nii.gz',
#    'D:/Datasets/Liver/7115793/20180222/D.nii.gz',
#    'D:/Datasets/Liver/7115793/20180222/label.nii.gz',
#    'D:/Datasets/Liver/7115793/20180222/P.nii.gz',
#    'D:/Datasets/Liver/7115793/20180222/Seg/liver.nii.gz'],
#   '20180629': ['D:/Datasets/Liver/7115793/20180629/A.nii.gz',
#    'D:/Datasets/Liver/7115793/20180629/D.nii.gz',
#    'D:/Datasets/Liver/7115793/20180629/label.nii.gz',
#    'D:/Datasets/Liver/7115793/20180629/P.nii.gz',
#    'D:/Datasets/Liver/7115793/20180629/Seg/liver.nii.gz']},
#  '7117281': {'20170525': ['D:/Datasets/Liver/7117281/20170525/A.nii.gz',
#    'D:/Datasets/Liver/7117281/20170525/D.nii.gz',
#    'D:/Datasets/Liver/7117281/20170525/label.nii.gz',
#    'D:/Datasets/Liver/7117281/20170525/P.nii.gz',
#    'D:/Datasets/Liver/7117281/20170525/Seg/liver.nii.gz'],
#   '20170829': ['D:/Datasets/Liver/7117281/20170829/A.nii.gz',
#    'D:/Datasets/Liver/7117281/20170829/D.nii.gz',
#    'D:/Datasets/Liver/7117281/20170829/label.nii.gz',
#    'D:/Datasets/Liver/7117281/20170829/P.nii.gz',
#    'D:/Datasets/Liver/7117281/20170829/Seg/liver.nii.gz'],
#   '20171205': ['D:/Datasets/Liver/7117281/20171205/A.nii.gz',
#    'D:/Datasets/Liver/7117281/20171205/D.nii.gz',
#    'D:/Datasets/Liver/7117281/20171205/label.nii.gz',
#    'D:/Datasets/Liver/7117281/20171205/P.nii.gz',
#    'D:/Datasets/Liver/7117281/20171205/Seg/liver.nii.gz']},
#  '7120112': {'20171025': ['D:/Datasets/Liver/7120112/20171025/A.nii.gz',
#    'D:/Datasets/Liver/7120112/20171025/D.nii.gz',
#    'D:/Datasets/Liver/7120112/20171025/label.nii.gz',
#    'D:/Datasets/Liver/7120112/20171025/P.nii.gz',
#    'D:/Datasets/Liver/7120112/20171025/Seg/liver.nii.gz'],
#   '20180124': ['D:/Datasets/Liver/7120112/20180124/A.nii.gz',
#    'D:/Datasets/Liver/7120112/20180124/D.nii.gz',
#    'D:/Datasets/Liver/7120112/20180124/label.nii.gz',
#    'D:/Datasets/Liver/7120112/20180124/P.nii.gz',
#    'D:/Datasets/Liver/7120112/20180124/Seg/liver.nii.gz']},
#  '7124641': {'20181026': ['D:/Datasets/Liver/7124641/20181026/A.nii.gz',
#    'D:/Datasets/Liver/7124641/20181026/D.nii.gz',
#    'D:/Datasets/Liver/7124641/20181026/label.nii.gz',
#    'D:/Datasets/Liver/7124641/20181026/P.nii.gz',
#    'D:/Datasets/Liver/7124641/20181026/Seg/liver.nii.gz'],
#   '20190201': ['D:/Datasets/Liver/7124641/20190201/A.nii.gz',
#    'D:/Datasets/Liver/7124641/20190201/D.nii.gz',
#    'D:/Datasets/Liver/7124641/20190201/label.nii.gz',
#    'D:/Datasets/Liver/7124641/20190201/P.nii.gz',
#    'D:/Datasets/Liver/7124641/20190201/Seg/liver.nii.gz'],
#   '20190521': ['D:/Datasets/Liver/7124641/20190521/A.nii.gz',
#    'D:/Datasets/Liver/7124641/20190521/D.nii.gz',
#    'D:/Datasets/Liver/7124641/20190521/label.nii.gz',
#    'D:/Datasets/Liver/7124641/20190521/P.nii.gz',
#    'D:/Datasets/Liver/7124641/20190521/Seg/liver.nii.gz']},
#  '7130538': {'20190531': ['D:/Datasets/Liver/7130538/20190531/A.nii.gz',
#    'D:/Datasets/Liver/7130538/20190531/D.nii.gz',
#    'D:/Datasets/Liver/7130538/20190531/label.nii.gz',
#    'D:/Datasets/Liver/7130538/20190531/P.nii.gz',
#    'D:/Datasets/Liver/7130538/20190531/Seg/liver.nii.gz'],
#   '20190729': ['D:/Datasets/Liver/7130538/20190729/A.nii.gz',
#    'D:/Datasets/Liver/7130538/20190729/D.nii.gz',
#    'D:/Datasets/Liver/7130538/20190729/label.nii.gz',
#    'D:/Datasets/Liver/7130538/20190729/P.nii.gz',
#    'D:/Datasets/Liver/7130538/20190729/Seg/liver.nii.gz']},
#  '7137823': {'20180305': ['D:/Datasets/Liver/7137823/20180305/A.nii.gz',
#    'D:/Datasets/Liver/7137823/20180305/D.nii.gz',
#    'D:/Datasets/Liver/7137823/20180305/label.nii.gz',
#    'D:/Datasets/Liver/7137823/20180305/P.nii.gz',
#    'D:/Datasets/Liver/7137823/20180305/Seg/liver.nii.gz'],
#   '20180611': ['D:/Datasets/Liver/7137823/20180611/A.nii.gz',
#    'D:/Datasets/Liver/7137823/20180611/D.nii.gz',
#    'D:/Datasets/Liver/7137823/20180611/label.nii.gz',
#    'D:/Datasets/Liver/7137823/20180611/P.nii.gz',
#    'D:/Datasets/Liver/7137823/20180611/Seg/liver.nii.gz'],
#   '20180907': ['D:/Datasets/Liver/7137823/20180907/A.nii.gz',
#    'D:/Datasets/Liver/7137823/20180907/D.nii.gz',
#    'D:/Datasets/Liver/7137823/20180907/label.nii.gz',
#    'D:/Datasets/Liver/7137823/20180907/P.nii.gz',
#    'D:/Datasets/Liver/7137823/20180907/Seg/liver.nii.gz']},
#  '7147888': {'20191127': ['D:/Datasets/Liver/7147888/20191127/A.nii.gz',
#    'D:/Datasets/Liver/7147888/20191127/D.nii.gz',
#    'D:/Datasets/Liver/7147888/20191127/label.nii.gz',
#    'D:/Datasets/Liver/7147888/20191127/P.nii.gz',
#    'D:/Datasets/Liver/7147888/20191127/Seg/liver.nii.gz'],
#   '20200313': ['D:/Datasets/Liver/7147888/20200313/A.nii.gz',
#    'D:/Datasets/Liver/7147888/20200313/D.nii.gz',
#    'D:/Datasets/Liver/7147888/20200313/label.nii.gz',
#    'D:/Datasets/Liver/7147888/20200313/P.nii.gz',
#    'D:/Datasets/Liver/7147888/20200313/Seg/liver.nii.gz']},
#  '7158322': {'20180921': ['D:/Datasets/Liver/7158322/20180921/A.nii.gz',
#    'D:/Datasets/Liver/7158322/20180921/D.nii.gz',
#    'D:/Datasets/Liver/7158322/20180921/label.nii.gz',
#    'D:/Datasets/Liver/7158322/20180921/P.nii.gz',
#    'D:/Datasets/Liver/7158322/20180921/Seg/liver.nii.gz'],
#   '20181219': ['D:/Datasets/Liver/7158322/20181219/A.nii.gz',
#    'D:/Datasets/Liver/7158322/20181219/D.nii.gz',
#    'D:/Datasets/Liver/7158322/20181219/label.nii.gz',
#    'D:/Datasets/Liver/7158322/20181219/P.nii.gz',
#    'D:/Datasets/Liver/7158322/20181219/Seg/liver.nii.gz']},
#  '7169364': {'20190801': ['D:/Datasets/Liver/7169364/20190801/A.nii.gz',
#    'D:/Datasets/Liver/7169364/20190801/D.nii.gz',
#    'D:/Datasets/Liver/7169364/20190801/label.nii.gz',
#    'D:/Datasets/Liver/7169364/20190801/P.nii.gz',
#    'D:/Datasets/Liver/7169364/20190801/Seg/liver.nii.gz']},
#  '7170537': {'20200413': ['D:/Datasets/Liver/7170537/20200413/A.nii.gz',
#    'D:/Datasets/Liver/7170537/20200413/D.nii.gz',
#    'D:/Datasets/Liver/7170537/20200413/label.nii.gz',
#    'D:/Datasets/Liver/7170537/20200413/P.nii.gz',
#    'D:/Datasets/Liver/7170537/20200413/Seg/liver.nii.gz']},
#  '7207169': {'20201020': ['D:/Datasets/Liver/7207169/20201020/A.nii.gz',
#    'D:/Datasets/Liver/7207169/20201020/D.nii.gz',
#    'D:/Datasets/Liver/7207169/20201020/label.nii.gz',
#    'D:/Datasets/Liver/7207169/20201020/P.nii.gz',
#    'D:/Datasets/Liver/7207169/20201020/Seg/liver.nii.gz'],
#   '20210111': ['D:/Datasets/Liver/7207169/20210111/A.nii.gz',
#    'D:/Datasets/Liver/7207169/20210111/D.nii.gz',
#    'D:/Datasets/Liver/7207169/20210111/label.nii.gz',
#    'D:/Datasets/Liver/7207169/20210111/P.nii.gz',
#    'D:/Datasets/Liver/7207169/20210111/Seg/liver.nii.gz']}}

# %%
seed_everything(CFG["SEED"])

# %%
import torch, torchvision
import numpy as np
from torch.utils.data import Dataset, DataLoader, random_split
import nibabel as nib
from basic_setup import seed_everything, CFG
from readpath import path_dict

seed_everything(CFG["SEED"])

class LiverDataset(Dataset):
    def __init__(self, dict, transform=None):
        self.dict = dict
        self.transform = transform
    
    def __len__(self):
        return len(self.dict)
    
    def __get_voxel__(self, path):  # (384, 384, 96)
        voxel = nib.load(path).get_fdata()
        return voxel
    
    def __get_date__(self, ID):
        return list(self.dict[ID].keys())
    
    def __merge_APD__(self, A, P, D):  # Needs improvement
        return (A + P + D) / 3
    
    def __normalize__(self, voxel):
        minimum = np.min(voxel)
        maximum = np.max(voxel)
        return ( (voxel - minimum) / (maximum - minimum) * 255 ).astype(np.uint8)

    def __getitem__(self, index):
        ID = list(self.dict.keys())[index]
        date_list = self.__get_date__(ID)
        path_list = self.dict[ID][date_list[0]]  # Use data from the 1st date ONLY
        A = self.__get_voxel__(path_list[0])
        P = self.__get_voxel__(path_list[3])
        D = self.__get_voxel__(path_list[1])
        label = self.__get_voxel__(path_list[2])
        merged = self.__merge_APD__(A, P, D)

        if self.transform is not None:
            merged = self.transform(merged)

        return merged.unsqueeze(0), torchvision.transforms.ToTensor()(label).unsqueeze(0)

train_transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor()
])

test_ratio = CFG["TEST_PORTION"]
data_dict = path_dict("D:/Datasets/Liver/")
total_dataset = LiverDataset(data_dict, train_transform)
train_set, test_set = random_split(total_dataset, [len(total_dataset)-int(len(total_dataset)*test_ratio), int(len(total_dataset)*test_ratio)])
train_loader = DataLoader(train_set, batch_size=CFG["BATCH_SIZE"], shuffle=True)
test_loader = DataLoader(test_set, batch_size=CFG["BATCH_SIZE"], shuffle=True)

# %%
import torch
import torch.nn as nn
from basic_setup import CFG, device

class LiTSModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.InitialBlock = nn.Sequential(
            nn.Conv3d(in_channels=1, out_channels=2, kernel_size=1, stride=1),  # Channel -> DOUBLE (1x1 Conv)
            nn.BatchNorm3d(num_features=2),
            nn.ReLU(),
            nn.MaxPool3d(2, 2)  # Img_size -> HALF
        )

        self.ResBlock1 = nn.Sequential(
            nn.Conv3d(2, 2, 1, 1),  # K=1, S=1, P=0 (O = I) -> just activation
            nn.BatchNorm3d(2),
            nn.ReLU(),
            nn.Conv3d(2, 4, 7, 2, 3),  # K=7, S=2, P=3 (O = I/2)
            nn.BatchNorm3d(4),
            nn.ReLU(),
            nn.Conv3d(4, 4, 1, 1),  # K=1, S=1, P=0 (O = I) -> just activation
            nn.BatchNorm3d(4),
            nn.ReLU(),
            nn.Dropout(p=0.5)
        )

        self.ResBlock2 = nn.Sequential(
            nn.Conv3d(4, 4, 1, 1),  # K=1, S=1, P=0 (O = I) -> just activation
            nn.BatchNorm3d(4),
            nn.ReLU(),
            nn.Conv3d(4, 8, 7, 2, 3),  # K=7, S=2, P=3 (O = I/2)
            nn.BatchNorm3d(8),
            nn.ReLU(),
            nn.Conv3d(8, 8, 1, 1),  # K=1, S=1, P=0 (O = I) -> just activation
            nn.BatchNorm3d(8),
            nn.ReLU(),
            nn.Dropout(p=0.5)
        )

        self.ResBlock3 = nn.Sequential(
            nn.Conv3d(8, 8, 1, 1),  # K=1, S=1, P=0 (O = I) -> just activation
            nn.BatchNorm3d(8),
            nn.ReLU(),
            nn.Conv3d(8, 16, 7, 2, 3),  # K=7, S=2, P=3 (O = I/2)
            nn.BatchNorm3d(16),
            nn.ReLU(),
            nn.Conv3d(16, 16, 1, 1),  # K=1, S=1, P=0 (O = I) -> just activation
            nn.BatchNorm3d(16),
            nn.ReLU(),
            nn.Dropout(p=0.5)
        )

        self.SkipConnection1 = nn.Sequential(
            nn.Conv3d(in_channels=2, out_channels=4, kernel_size=1, stride=1),
            nn.BatchNorm3d(4),
            nn.ReLU(),
            nn.MaxPool3d(2, 2),
            nn.Dropout(p=0.5)
        )

        self.SkipConnection2 = nn.Sequential(
            nn.Conv3d(in_channels=4, out_channels=8, kernel_size=1, stride=1),
            nn.BatchNorm3d(8),
            nn.ReLU(),
            nn.MaxPool3d(2, 2),
            nn.Dropout(p=0.5)
        )

        self.SkipConnection3 = nn.Sequential(
            nn.Conv3d(in_channels=8, out_channels=16, kernel_size=1, stride=1),
            nn.BatchNorm3d(16),
            nn.ReLU(),
            nn.MaxPool3d(2, 2),
            nn.Dropout(p=0.5)
        )
        
        self.activation = nn.ReLU()
        self.maxpool = nn.MaxPool3d(2, 2)
        self.fc = nn.Linear(in_features=16*4*4*2, out_features=2)
        self.softmax = nn.Softmax()
    
    def forward(self, x):
        x = self.InitialBlock(x)
        x = self.ResBlock1(x) + self.SkipConnection1(x)
        x = self.ResBlock2(x) + self.SkipConnection2(x)
        x = self.ResBlock3(x) + self.SkipConnection3(x)

        x = self.maxpool(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        x = self.softmax(x)

        return x

# %%
def calculate_iou(pred, gt):
    return

# %%
import numpy as np
import matplotlib.pyplot as plt

def train_plot(loss_hist, iou_hist):
    plt.figure(figsize=(20,10))
    plt.subplot(121), plt.plot(loss_hist, label='train_loss')
    plt.title('Train Loss')

    plt.subplot(122), plt.plot(iou_hist, label='train_iou')
    plt.title('Train IOU')
    plt.savefig("./Figures/Train.jpg")
    return

def test_plot(pred, gt):
    from utils import calculate_iou
    iou_scores = calculate_iou(pred, gt)
    plt.figure(figsize=(20,10))
    plt.plot(iou_scores, label='test_iou')
    plt.title('Train Loss')
    plt.savefig("./Figures/Test.jpg")
    return

# %%
import os, time
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from basic_setup import CFG, device
from construct_dataset import train_loader
from construct_model import LiTSModel
from plot_results import train_plot

def train_loop(dataloader, model, optimizer, loss_fn, model_save_path):
    model.train()

    size = len(dataloader)
    datasize = len(dataloader.dataset)

    loss_hist=[]
    acc_hist=[]

    for epoch in range(CFG["EPOCHS"]):
        epoch_start = time.time()

        loss_item=0
        correct=0
        print(f"Start epoch : {epoch+1}")
        for batch, (X,y) in enumerate(dataloader):
            X = X.to(device).float()
            y = y.to(device).float()

            output = model(X)

            loss = loss_fn(output, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            loss_item += loss.item()

            correct+=(output.argmax(1)==y.argmax(1)).detach().cpu().sum().item()

            if batch % 20 == 0:
                print(f"Batch loss : {(loss):>.5f} {batch}/{size}")

        scheduler.step()
        
        loss_hist.append(loss_item/size)
        acc_hist.append(correct/datasize*100)

        print(f"Loss : {(loss_item/size):>.5f} ACC : {(correct/datasize*100):>.2f}%")

        epoch_end = time.time()
        print(f"End epoch : {epoch+1}")
        print(f"Epoch time : {(epoch_end-epoch_start)//60} min {(epoch_end-epoch_start)%60} sec")
        print()

    torch.save(model.state_dict(), model_save_path)

    return loss_hist, acc_hist

model = LiTSModel().to(device)
loss = nn.BCELoss().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=CFG["LR"], weight_decay=0.1)  # Weight decay (L2 regularization)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

loss_hist, acc_hist = train_loop(train_loader, model, optimizer, loss, CFG["model_save_path"])

train_plot(loss_hist, acc_hist)

# %%
import torch
from basic_setup import CFG, device
from construct_dataset import test_loader
from construct_model import LiTSModel
from plot_results import test_plot

def test_loop(dataloader, model, model_path):
    model.load_state_dict(torch.load(model_path))
    model.eval()

    pred=[]
    target=[]

    for (X,y) in dataloader:
        for t in y:
            target.append(t[1].detach().tolist())

        X = X.to(device).float()
        y = y.to(device).float()

        output = model(X)

        for o in output:
            print(f"Output: {o}")
            pred.append(o[1].detach().cpu().tolist())

    return target, pred

model = LiTSModel().to(device)

target, pred = test_loop(test_loader, model, CFG["model_save_path"])

test_plot(target, pred)
